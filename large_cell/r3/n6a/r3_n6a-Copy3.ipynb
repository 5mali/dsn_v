# %%
# %matplotlib inline

from os.path import dirname, abspath, join
from os import getcwd
import sys

THIS_DIR = getcwd()
CLASS_DIR = abspath(join(THIS_DIR, '../../..', 'dsnclasses'))
sys.path.append(CLASS_DIR)

import random
import string
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from IPython.display import clear_output

from ENOlarge import ENO
from CAPMr3 import CAPM
from NN6a import DQN as DQN
from globalvar import *

# %%
def test_model(TEST_LOCATION, TEST_YEAR, MODELFILE, dqn):

    print('\nYear run test (Greedy Policy)')

#     dqn = DQN()
    capm = CAPM(TEST_LOCATION,TEST_YEAR, shuffle=False, trainmode=False) #if reset is True
    capm.eno = ENO(TEST_LOCATION,TEST_YEAR, shuffle=False, day_balance=False) #instantiate the environment inside the CAPM class
    capm.HMAX = capm.eno.SMAX #maximum power output of solar cell is set in CAPM object using the value in ENO object

    # load the required model
    dqn.eval_net.load_state_dict(torch.load(MODELFILE))
    dqn.eval_net.eval()
    print('Model Used: ',MODELFILE)

    s, r, day_end, year_end = capm.reset()
    yr_test_record = np.empty(4)

    while True:
        a = dqn.choose_greedy_action(s)

        #state = [batt, enp, henergy, fcast]
        yr_test_record = np.vstack((yr_test_record, [s[0],s[2],r, a])) #record battery, henergy, reward and action

        # take action
        s_, r, day_end, year_end = capm.step(a)

        if year_end:
            print("End of Test")
            break

        s = s_

    yr_test_record = np.delete(yr_test_record, 0, 0) #remove the first row which is garbage
    NO_OF_DAYS = capm.eno.NO_OF_DAYS
    yr_test_reward_rec = yr_test_record[:,2]
    yr_test_reward_rec = yr_test_reward_rec[yr_test_reward_rec != 0]
    
    #Plot the reward and battery for the entire year run
    title = TEST_LOCATION.upper() + ',' + str(TEST_YEAR)
    print('Average Reward for',title, '=', np.mean(yr_test_reward_rec))

    fig = plt.figure(figsize=(24,3))
    fig.suptitle(title, fontsize=15)

#     ax1 = fig.add_subplot(211)
#     ax1.plot(yr_test_reward_rec)
#     ax1.set_title("\n\nYear Run Reward")
#     ax1.set_ylim([-3,1])

    ax2 = fig.add_subplot(111)
    ax2.plot(yr_test_record[:,0],'r')
    ax2.set_title("\n\nYear Run Battery")
    ax2.set_ylim([0,1])
    plt.sca(ax2)
    plt.xticks(np.arange(0, NO_OF_DAYS*24, 50*24),np.arange(0,NO_OF_DAYS,50))

    fig.tight_layout()
    plt.show()    
    return 0

# %%
#TRAIN USING data from TOKYO, WAKKANAI and MINAMIDAITO FROM 2005 to 2014
dqn = DQN()

NO_OF_ITERATIONS = 100

best_iteration = -1
best_avg_reward = -1000 #initialize best average reward to very low value
PFILENAME = ''.join(random.choice(string.ascii_uppercase + string.digits) for _ in range(8)) #create random filename
BFILENAME = "best"+PFILENAME + ".pt" #this file stores the best model
TFILENAME = "terminal"+PFILENAME + ".pt" #this file stores the last model

avg_reward_rec = [] #record the yearly average rewards over the entire duration of training
print('\nTRAINING IN PROGRESS\n')

for iteration in range(NO_OF_ITERATIONS):
    LOCATION = random.choice(['tokyo','wakkanai','minamidaito'])
    YEAR = random.choice(np.arange(2005,2015))
    capm = CAPM(LOCATION,YEAR,shuffle=True, trainmode=True) #instantiate the CAPM class
    capm.eno = ENO(LOCATION,YEAR, shuffle=True, day_balance=True) #instantiate the environment inside the CAPM class
    capm.HMAX = capm.eno.SMAX #maximum power output of solar cell is set in CAPM object using the value in ENO object
#     clear_output()
    print('Iteration {}:  {}, {} '.format(iteration, LOCATION.upper(), YEAR))

    s, r, day_end, year_end = capm.reset()
    record = np.empty(4) #record for battery, henergy, reward and action
    transition_rec = np.zeros((capm.eno.TIME_STEPS, N_STATES * 2 + 2)) #record all the transition in one day

    while True:
        a = dqn.choose_action(s)

        # present state = [batt, enp, henergy]
        record = np.vstack((record, [s[0],s[2],r, a])) # record battery, henergy, reward and action for troubleshooting
                                                       # However, we are interested only in the reward

        # take action
        s_, r, day_end, year_end = capm.step(a)

        temp_transitions = np.hstack((s, [a, r], s_))
        transition_rec[capm.eno.hr-1,:] = temp_transitions

        if (day_end):
            transition_rec[:,5] = r #broadcast reward to all states
            decay_factor = [i for i in (LAMBDA**n for n in reversed(range(0, capm.eno.TIME_STEPS)))]
            transition_rec[:,5] = transition_rec[:,5] * decay_factor #decay reward proportionately
            dqn.store_day_transition(transition_rec)

        if dqn.memory_counter > MEMORY_CAPACITY:
            dqn.learn()

        if (year_end):
    #             print("End of Year")
            break

        # transition to new state
        s = s_

    record = np.delete(record, 0, 0) #remove the first row which is garbage
    reward_rec = record[:,2] #extract reward information from the record array
    reward_rec = reward_rec[reward_rec != 0] #remove all zero rewards in the middle of the days
    print("Average Reward \t\t= {:8.3f}".format(np.mean(reward_rec)))

    # Check if reward beats the High Score and possible save it    
    if (iteration > 19): #save the best models only after 20 iterations
        print("Best Score \t = {:8.3f} @ Iteration No. {}".format(best_avg_reward, best_iteration))
        if(best_avg_reward < np.mean(reward_rec)):
            best_iteration = iteration
            best_avg_reward = np.mean(reward_rec)
            print("Saving Model")
            torch.save(dqn.eval_net.state_dict(), BFILENAME)
    else:
        print("\r")
    # Log the average reward in avg_reward_rec
    avg_reward_rec = np.append(avg_reward_rec, np.mean(reward_rec))

    # End of training
# Save the last model
torch.save(dqn.eval_net.state_dict(), TFILENAME) 

# Plot the average reward log
plt.plot(avg_reward_rec,'b')
plt.ylim([-3,1])
# Out:
# TRAINING IN PROGRESS
#
# Iteration 0:  WAKKANAI, 2013
# Average Reward 		=   -1.041
#
# Iteration 1:  MINAMIDAITO, 2006
# Average Reward 		=   -1.445
#
# Iteration 2:  WAKKANAI, 2007
# Average Reward 		=   -1.589
#
# Iteration 3:  MINAMIDAITO, 2012
# Average Reward 		=   -1.608
#
# Iteration 4:  MINAMIDAITO, 2005
# Average Reward 		=   -1.392
#
# Iteration 5:  WAKKANAI, 2014
# Average Reward 		=   -1.545
#
# Iteration 6:  TOKYO, 2006
# Average Reward 		=   -1.571
#
# Iteration 7:  WAKKANAI, 2010
# Average Reward 		=   -1.565
#
# Iteration 8:  TOKYO, 2009
# Average Reward 		=   -1.529
#
# Iteration 9:  TOKYO, 2014
# Average Reward 		=   -1.415
#
# Iteration 10:  MINAMIDAITO, 2008
# Average Reward 		=   -1.605
#
# Iteration 11:  TOKYO, 2011
# Average Reward 		=   -1.561
#
# Iteration 12:  MINAMIDAITO, 2014
# Average Reward 		=   -1.478
#
# Iteration 13:  WAKKANAI, 2011
# Average Reward 		=   -1.642
#
# Iteration 14:  MINAMIDAITO, 2009
# Average Reward 		=   -1.590
#
# Iteration 15:  WAKKANAI, 2012
# Average Reward 		=   -1.541
#
# Iteration 16:  WAKKANAI, 2013
# Average Reward 		=   -1.549
#
# Iteration 17:  WAKKANAI, 2006
# Average Reward 		=   -1.545
#
# Iteration 18:  MINAMIDAITO, 2009
# Average Reward 		=   -1.868
#
# Iteration 19:  MINAMIDAITO, 2009
# Average Reward 		=   -1.538
#
# Iteration 20:  WAKKANAI, 2012
# Average Reward 		=   -1.535
# Best Score 	 = -1000.000 @ Iteration No. -1
# Saving Model
# Iteration 21:  MINAMIDAITO, 2012
# Average Reward 		=   -1.584
# Best Score 	 =   -1.535 @ Iteration No. 20
# Iteration 22:  MINAMIDAITO, 2012
# Average Reward 		=   -1.410
# Best Score 	 =   -1.535 @ Iteration No. 20
# Saving Model
# Iteration 23:  MINAMIDAITO, 2014
# Average Reward 		=   -1.614
# Best Score 	 =   -1.410 @ Iteration No. 22
# Iteration 24:  TOKYO, 2014
# Average Reward 		=   -1.583
# Best Score 	 =   -1.410 @ Iteration No. 22
# Iteration 25:  MINAMIDAITO, 2007
# Average Reward 		=   -1.477
# Best Score 	 =   -1.410 @ Iteration No. 22
# Iteration 26:  MINAMIDAITO, 2013
# Average Reward 		=   -1.594
# Best Score 	 =   -1.410 @ Iteration No. 22
# Iteration 27:  MINAMIDAITO, 2011
# Average Reward 		=   -1.461
# Best Score 	 =   -1.410 @ Iteration No. 22
# Iteration 28:  WAKKANAI, 2007
# Average Reward 		=   -1.432
# Best Score 	 =   -1.410 @ Iteration No. 22
# Iteration 29:  MINAMIDAITO, 2010
# Average Reward 		=   -1.596
# Best Score 	 =   -1.410 @ Iteration No. 22
# Iteration 30:  MINAMIDAITO, 2008
# Average Reward 		=   -1.452
# Best Score 	 =   -1.410 @ Iteration No. 22
# Iteration 31:  TOKYO, 2007
# Average Reward 		=   -1.553
# Best Score 	 =   -1.410 @ Iteration No. 22
# Iteration 32:  WAKKANAI, 2010
# Average Reward 		=   -1.571
# Best Score 	 =   -1.410 @ Iteration No. 22
# Iteration 33:  WAKKANAI, 2011
# Average Reward 		=   -1.557
# Best Score 	 =   -1.410 @ Iteration No. 22
# Iteration 34:  WAKKANAI, 2014
# Average Reward 		=   -1.692
# Best Score 	 =   -1.410 @ Iteration No. 22
# Iteration 35:  WAKKANAI, 2005
# Average Reward 		=   -1.578
# Best Score 	 =   -1.410 @ Iteration No. 22
# Iteration 36:  MINAMIDAITO, 2009
# Average Reward 		=   -1.590
# Best Score 	 =   -1.410 @ Iteration No. 22
# Iteration 37:  MINAMIDAITO, 2006
# Average Reward 		=   -1.481
# Best Score 	 =   -1.410 @ Iteration No. 22
# Iteration 38:  MINAMIDAITO, 2009
# Average Reward 		=   -1.439
# Best Score 	 =   -1.410 @ Iteration No. 22
# Iteration 39:  WAKKANAI, 2008
# Average Reward 		=   -1.353
# Best Score 	 =   -1.410 @ Iteration No. 22
# Saving Model
# Iteration 40:  WAKKANAI, 2009
# Average Reward 		=   -1.550
# Best Score 	 =   -1.353 @ Iteration No. 39
# Iteration 41:  MINAMIDAITO, 2012
# Average Reward 		=   -1.596
# Best Score 	 =   -1.353 @ Iteration No. 39
# Iteration 42:  MINAMIDAITO, 2008
# Average Reward 		=   -1.355
# Best Score 	 =   -1.353 @ Iteration No. 39
# Iteration 43:  TOKYO, 2009
# Average Reward 		=   -1.518
# Best Score 	 =   -1.353 @ Iteration No. 39
# Iteration 44:  MINAMIDAITO, 2009
# Average Reward 		=   -1.522
# Best Score 	 =   -1.353 @ Iteration No. 39
# Iteration 45:  WAKKANAI, 2007
# Average Reward 		=   -1.523
# Best Score 	 =   -1.353 @ Iteration No. 39
# Iteration 46:  MINAMIDAITO, 2006
# Average Reward 		=   -1.326
# Best Score 	 =   -1.353 @ Iteration No. 39
# Saving Model
# Iteration 47:  WAKKANAI, 2006
# Average Reward 		=   -1.632
# Best Score 	 =   -1.326 @ Iteration No. 46
# Iteration 48:  TOKYO, 2012
# Average Reward 		=   -1.528
# Best Score 	 =   -1.326 @ Iteration No. 46
# Iteration 49:  MINAMIDAITO, 2009
# Average Reward 		=   -1.508
# Best Score 	 =   -1.326 @ Iteration No. 46
# Iteration 50:  TOKYO, 2013
# Average Reward 		=   -1.467
# Best Score 	 =   -1.326 @ Iteration No. 46
# Iteration 51:  WAKKANAI, 2014
# Average Reward 		=   -1.459
# Best Score 	 =   -1.326 @ Iteration No. 46
# Iteration 52:  WAKKANAI, 2012
# Average Reward 		=   -1.712
# Best Score 	 =   -1.326 @ Iteration No. 46
# Iteration 53:  MINAMIDAITO, 2013
# Average Reward 		=   -1.658
# Best Score 	 =   -1.326 @ Iteration No. 46
# Iteration 54:  MINAMIDAITO, 2014
# Average Reward 		=   -1.294
# Best Score 	 =   -1.326 @ Iteration No. 46
# Saving Model
# Iteration 55:  MINAMIDAITO, 2005
# Average Reward 		=   -1.564
# Best Score 	 =   -1.294 @ Iteration No. 54
# Iteration 56:  TOKYO, 2009
# Average Reward 		=   -1.405
# Best Score 	 =   -1.294 @ Iteration No. 54
# Iteration 57:  WAKKANAI, 2005
# Average Reward 		=   -1.473
# Best Score 	 =   -1.294 @ Iteration No. 54
# Iteration 58:  WAKKANAI, 2008
# Average Reward 		=   -1.621
# Best Score 	 =   -1.294 @ Iteration No. 54
# Iteration 59:  MINAMIDAITO, 2014
# Average Reward 		=   -1.517
# Best Score 	 =   -1.294 @ Iteration No. 54
# Iteration 60:  TOKYO, 2013
# Average Reward 		=   -1.435
# Best Score 	 =   -1.294 @ Iteration No. 54
# Iteration 61:  TOKYO, 2011
# Average Reward 		=   -1.547
# Best Score 	 =   -1.294 @ Iteration No. 54
# Iteration 62:  TOKYO, 2005
# Average Reward 		=   -1.568
# Best Score 	 =   -1.294 @ Iteration No. 54
# Iteration 63:  MINAMIDAITO, 2011
# Average Reward 		=   -1.628
# Best Score 	 =   -1.294 @ Iteration No. 54
# Iteration 64:  MINAMIDAITO, 2013
# Average Reward 		=   -1.546
# Best Score 	 =   -1.294 @ Iteration No. 54
# Iteration 65:  TOKYO, 2014
# Average Reward 		=   -1.581
# Best Score 	 =   -1.294 @ Iteration No. 54
# Iteration 66:  TOKYO, 2014
# Average Reward 		=   -1.349
# Best Score 	 =   -1.294 @ Iteration No. 54
# Iteration 67:  WAKKANAI, 2005
# Average Reward 		=   -1.461
# Best Score 	 =   -1.294 @ Iteration No. 54
# Iteration 68:  WAKKANAI, 2010
# Average Reward 		=   -1.688
# Best Score 	 =   -1.294 @ Iteration No. 54
# Iteration 69:  WAKKANAI, 2012
# Average Reward 		=   -1.483
# Best Score 	 =   -1.294 @ Iteration No. 54
# Iteration 70:  MINAMIDAITO, 2013
# Average Reward 		=   -1.452
# Best Score 	 =   -1.294 @ Iteration No. 54
# Iteration 71:  WAKKANAI, 2014
# Average Reward 		=   -1.390
# Best Score 	 =   -1.294 @ Iteration No. 54
# Iteration 72:  MINAMIDAITO, 2013
# Average Reward 		=   -1.571
# Best Score 	 =   -1.294 @ Iteration No. 54
# Iteration 73:  TOKYO, 2009
# Average Reward 		=   -1.524
# Best Score 	 =   -1.294 @ Iteration No. 54
# Iteration 74:  WAKKANAI, 2007
# Average Reward 		=   -1.370
# Best Score 	 =   -1.294 @ Iteration No. 54
# Iteration 75:  WAKKANAI, 2012
# Average Reward 		=   -1.593
# Best Score 	 =   -1.294 @ Iteration No. 54
# Iteration 76:  TOKYO, 2007
# Average Reward 		=   -1.646
# Best Score 	 =   -1.294 @ Iteration No. 54
# Iteration 77:  MINAMIDAITO, 2008
# Average Reward 		=   -1.494
# Best Score 	 =   -1.294 @ Iteration No. 54
# Iteration 78:  WAKKANAI, 2011
# Average Reward 		=   -1.500
# Best Score 	 =   -1.294 @ Iteration No. 54
# Iteration 79:  TOKYO, 2013
# Average Reward 		=   -1.484
# Best Score 	 =   -1.294 @ Iteration No. 54
# Iteration 80:  TOKYO, 2013
# Average Reward 		=   -1.426
# Best Score 	 =   -1.294 @ Iteration No. 54
# Iteration 81:  TOKYO, 2013
# Average Reward 		=   -1.607
# Best Score 	 =   -1.294 @ Iteration No. 54
# Iteration 82:  TOKYO, 2006
# Average Reward 		=   -1.429
# Best Score 	 =   -1.294 @ Iteration No. 54
# Iteration 83:  WAKKANAI, 2005
# Average Reward 		=   -1.653
# Best Score 	 =   -1.294 @ Iteration No. 54
# Iteration 84:  TOKYO, 2010
# Average Reward 		=   -1.501
# Best Score 	 =   -1.294 @ Iteration No. 54
# Iteration 85:  TOKYO, 2013
# Average Reward 		=   -1.472
# Best Score 	 =   -1.294 @ Iteration No. 54
# Iteration 86:  TOKYO, 2007
# Average Reward 		=   -1.584
# Best Score 	 =   -1.294 @ Iteration No. 54
# Iteration 87:  TOKYO, 2013
# Average Reward 		=   -1.506
# Best Score 	 =   -1.294 @ Iteration No. 54
# Iteration 88:  TOKYO, 2013
# Average Reward 		=   -1.636
# Best Score 	 =   -1.294 @ Iteration No. 54
# Iteration 89:  TOKYO, 2009
# Average Reward 		=   -1.382
# Best Score 	 =   -1.294 @ Iteration No. 54
# Iteration 90:  WAKKANAI, 2006
# Average Reward 		=   -1.518
# Best Score 	 =   -1.294 @ Iteration No. 54
# Iteration 91:  WAKKANAI, 2007
# Average Reward 		=   -1.619
# Best Score 	 =   -1.294 @ Iteration No. 54
# Iteration 92:  WAKKANAI, 2005
# Average Reward 		=   -1.549
# Best Score 	 =   -1.294 @ Iteration No. 54
# Iteration 93:  WAKKANAI, 2012
# Average Reward 		=   -1.623
# Best Score 	 =   -1.294 @ Iteration No. 54
# Iteration 94:  MINAMIDAITO, 2008
# Average Reward 		=   -1.433
# Best Score 	 =   -1.294 @ Iteration No. 54
# Iteration 95:  MINAMIDAITO, 2014
# Average Reward 		=   -1.477
# Best Score 	 =   -1.294 @ Iteration No. 54
# Iteration 96:  WAKKANAI, 2005
# Average Reward 		=   -1.518
# Best Score 	 =   -1.294 @ Iteration No. 54
# Iteration 97:  WAKKANAI, 2012
# Average Reward 		=   -1.657
# Best Score 	 =   -1.294 @ Iteration No. 54
# Iteration 98:  TOKYO, 2006
# Average Reward 		=   -1.453
# Best Score 	 =   -1.294 @ Iteration No. 54
# Iteration 99:  WAKKANAI, 2008
# Average Reward 		=   -1.590
# Best Score 	 =   -1.294 @ Iteration No. 54
# (-3, 1)

# %%
#BFILENAME -> loads the best model
#TFILENAME -> loads the last model
MODELFILE = BFILENAME
TEST_YEAR = '2018'
dqn = DQN()
for TEST_LOCATION in ['tokyo','wakkanai','minamidaito']:
    test_model(TEST_LOCATION, TEST_YEAR, MODELFILE, dqn)
# Out:
# Year run test (Greedy Policy)
# Model Used:  bestR961Y8XD.pt
# End of Test
# Average Reward for TOKYO,2018 = -2.180078578944983
# Year run test (Greedy Policy)
# Model Used:  bestR961Y8XD.pt
# End of Test
# Average Reward for WAKKANAI,2018 = -2.4273780934132336
# Year run test (Greedy Policy)
# Model Used:  bestR961Y8XD.pt
# End of Test
# Average Reward for MINAMIDAITO,2018 = -2.344702013636268

# %%
MODELFILE = TFILENAME
TEST_YEAR = '2018'
dqn = DQN()
for TEST_LOCATION in ['tokyo','wakkanai','minamidaito']:
    test_model(TEST_LOCATION, TEST_YEAR, MODELFILE, dqn)
# Out:
# Year run test (Greedy Policy)
# Model Used:  terminalR961Y8XD.pt
# End of Test
# Average Reward for TOKYO,2018 = -2.1528695117444534
# Year run test (Greedy Policy)
# Model Used:  terminalR961Y8XD.pt
# End of Test
# Average Reward for WAKKANAI,2018 = -2.4419033698387067
# Year run test (Greedy Policy)
# Model Used:  terminalR961Y8XD.pt
# End of Test
# Average Reward for MINAMIDAITO,2018 = -2.307670414309043

# %%
# TEST_YEAR = 2018
# for TEST_LOCATION in ['tokyo','wakkanai','minamidaito']:
#     test_model(TEST_LOCATION, TEST_YEAR)

# %%
# dqn = DQN()
# capm = CAPM(TEST_LOCATION,TEST_YEAR, shuffle=False, trainmode=False) #if reset is True
# capm.eno = ENO(TEST_LOCATION,TEST_YEAR, shuffle=False, day_balance=False) #instantiate the environment inside the CAPM class
# capm.HMAX = capm.eno.SMAX #maximum power output of solar cell is set in CAPM object using the value in ENO object


# # load the required model
# dqn.eval_net.load_state_dict(torch.load(MODELFILE))
# dqn.eval_net.eval()
# print('Model Used: ',MODELFILE)

# s, r, day_end, year_end = capm.reset()
# yr_test_record = np.empty(4)

# while True:
#     a = dqn.choose_greedy_action(s)

#     #state = [batt, enp, henergy, fcast]
#     yr_test_record = np.vstack((yr_test_record, [s[0],s[2],r, a])) #record battery, henergy, reward and action

#     # take action
#     s_, r, day_end, year_end = capm.step(a)
    
# #     if day_end:
# #         if (capm.BMIN ==capm.batt or capm.batt == capm.BMAX):
# #             capm.batt = capm.BOPT
        

#     if year_end:
#         print("End of Test")
#         break

#     s = s_

# yr_test_record = np.delete(yr_test_record, 0, 0) #remove the first row which is garbage

# #Plot the reward and battery for the entire year run
# title = TEST_LOCATION.upper() + ',' + str(TEST_YEAR)

# NO_OF_DAYS = capm.eno.NO_OF_DAYS
# yr_test_reward_rec = yr_test_record[:,2]
# yr_test_reward_rec = yr_test_reward_rec[yr_test_reward_rec != 0]
# print('Average Reward for',title, '=', np.mean(yr_test_reward_rec))


# fig = plt.figure(figsize=(24,10))
# fig.suptitle(title, fontsize=15)

# #     ax1 = fig.add_subplot(211)
# #     ax1.plot(yr_test_reward_rec)
# #     ax1.set_title("\n\nYear Run Reward")
# #     ax1.set_ylim([-3,1])

# ax2 = fig.add_subplot(111)
# ax2.plot(yr_test_record[:,0],'r')
# ax2.set_title("\n\nYear Run Battery")
# ax2.set_ylim([0,1])
# plt.sca(ax2)
# plt.xticks(np.arange(0, NO_OF_DAYS*24, 50*24),np.arange(0,NO_OF_DAYS,50))

# fig.tight_layout()
# plt.show()

# %%
# #Plot the reward and battery for the entire year run on a day by day basis
# title = TEST_LOCATION.upper() + ',' + str(TEST_YEAR)
# TIME_AXIS = np.arange(0,capm.eno.TIME_STEPS)
# for DAY in range(150,170):#capm.eno.NO_OF_DAYS):
#     START = DAY*24
#     END = START+24

#     daytitle = title + ' - DAY ' + str(DAY)
#     fig = plt.figure(figsize=(16,4))
#     st = fig.suptitle(daytitle)

#     ax2 = fig.add_subplot(121)
#     ax2.plot(yr_test_record[START:END,1],'g')
#     ax2.set_title("HARVESTED ENERGY")
#     plt.xlabel("Hour")
#     ax2.set_ylim([0,1])

#     #plot battery for year run
#     ax1 = fig.add_subplot(122)
#     ax1.plot(TIME_AXIS,yr_test_record[START:END,0],'r') 
# #     ax1.plot(TIME_AXIS, np.ones(capm.eno.TIME_STEPS)*capm.BOPT/capm.BMAX,'r--')
#     ax1.plot(TIME_AXIS, np.ones(capm.eno.TIME_STEPS)*yr_test_record[START,0],'r--')
#     ax1.text(0.1, 0.2, "BINIT = %.2f\n" %(yr_test_record[START,0]),fontsize=11, ha='left')
#     ax1.text(0.1, 0.4, "TENP = %.2f\n" %(capm.BOPT/capm.BMAX-yr_test_record[END,0]),fontsize=11, ha='left')
#     ax1.text(0.1, 0.3, "BMEAN = %.2f\n" %(np.mean(yr_test_record[START:END,0])),fontsize=11, ha='left')



#     ax1.set_title("YEAR RUN TEST")
#     if END < (capm.eno.NO_OF_DAYS*capm.eno.TIME_STEPS):
#         ax1.text(0.1, 0, "REWARD = %.2f\n" %(yr_test_record[END,2]),fontsize=13, ha='left')
#     plt.xlabel("Hour")
#     ax1.set_ylabel('Battery', color='r',fontsize=12)
#     ax1.set_ylim([0,1])

#     #plot actions for year run
#     ax1a = ax1.twinx()
#     ax1a.plot(yr_test_record[START:END,3])
#     ax1a.set_ylim([0,N_ACTIONS])
#     ax1a.set_ylabel('Duty Cycle', color='b',fontsize=12)

#     fig.tight_layout()
#     st.set_y(0.95)
#     fig.subplots_adjust(top=0.75)
#     plt.show()
