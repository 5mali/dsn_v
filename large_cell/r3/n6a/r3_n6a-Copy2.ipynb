# %%
# %matplotlib inline

from os.path import dirname, abspath, join
from os import getcwd
import sys

THIS_DIR = getcwd()
CLASS_DIR = abspath(join(THIS_DIR, '../../..', 'dsnclasses'))
sys.path.append(CLASS_DIR)

import random
import string
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from IPython.display import clear_output

from ENOlarge import ENO
from CAPMr3 import CAPM
from NN6a import DQN as DQN
from globalvar import *

# %%
def test_model(TEST_LOCATION, TEST_YEAR, MODELFILE, dqn):

    print('\nYear run test (Greedy Policy)')

#     dqn = DQN()
    capm = CAPM(TEST_LOCATION,TEST_YEAR, shuffle=False, trainmode=False) #if reset is True
    capm.eno = ENO(TEST_LOCATION,TEST_YEAR, shuffle=False, day_balance=False) #instantiate the environment inside the CAPM class
    capm.HMAX = capm.eno.SMAX #maximum power output of solar cell is set in CAPM object using the value in ENO object

    # load the required model
    dqn.eval_net.load_state_dict(torch.load(MODELFILE))
    dqn.eval_net.eval()
    print('Model Used: ',MODELFILE)

    s, r, day_end, year_end = capm.reset()
    yr_test_record = np.empty(4)

    while True:
        a = dqn.choose_greedy_action(s)

        #state = [batt, enp, henergy, fcast]
        yr_test_record = np.vstack((yr_test_record, [s[0],s[2],r, a])) #record battery, henergy, reward and action

        # take action
        s_, r, day_end, year_end = capm.step(a)

        if year_end:
            print("End of Test")
            break

        s = s_

    yr_test_record = np.delete(yr_test_record, 0, 0) #remove the first row which is garbage
    NO_OF_DAYS = capm.eno.NO_OF_DAYS
    yr_test_reward_rec = yr_test_record[:,2]
    yr_test_reward_rec = yr_test_reward_rec[yr_test_reward_rec != 0]
    
    #Plot the reward and battery for the entire year run
    title = TEST_LOCATION.upper() + ',' + str(TEST_YEAR)
    print('Average Reward for',title, '=', np.mean(yr_test_reward_rec))

    fig = plt.figure(figsize=(24,3))
    fig.suptitle(title, fontsize=15)

#     ax1 = fig.add_subplot(211)
#     ax1.plot(yr_test_reward_rec)
#     ax1.set_title("\n\nYear Run Reward")
#     ax1.set_ylim([-3,1])

    ax2 = fig.add_subplot(111)
    ax2.plot(yr_test_record[:,0],'r')
    ax2.set_title("\n\nYear Run Battery")
    ax2.set_ylim([0,1])
    plt.sca(ax2)
    plt.xticks(np.arange(0, NO_OF_DAYS*24, 50*24),np.arange(0,NO_OF_DAYS,50))

    fig.tight_layout()
    plt.show()    
    return 0

# %%
#TRAIN USING data from TOKYO, WAKKANAI and MINAMIDAITO FROM 2005 to 2014
dqn = DQN()

NO_OF_ITERATIONS = 100

best_iteration = -1
best_avg_reward = -1000 #initialize best average reward to very low value
PFILENAME = ''.join(random.choice(string.ascii_uppercase + string.digits) for _ in range(8)) #create random filename
BFILENAME = "best"+PFILENAME + ".pt" #this file stores the best model
TFILENAME = "terminal"+PFILENAME + ".pt" #this file stores the last model

avg_reward_rec = [] #record the yearly average rewards over the entire duration of training
print('\nTRAINING IN PROGRESS\n')

for iteration in range(NO_OF_ITERATIONS):
    LOCATION = random.choice(['tokyo','wakkanai','minamidaito'])
    YEAR = random.choice(np.arange(2005,2015))
    capm = CAPM(LOCATION,YEAR,shuffle=True, trainmode=True) #instantiate the CAPM class
    capm.eno = ENO(LOCATION,YEAR, shuffle=True, day_balance=True) #instantiate the environment inside the CAPM class
    capm.HMAX = capm.eno.SMAX #maximum power output of solar cell is set in CAPM object using the value in ENO object
#     clear_output()
    print('Iteration {}:  {}, {} '.format(iteration, LOCATION.upper(), YEAR))

    s, r, day_end, year_end = capm.reset()
    record = np.empty(4) #record for battery, henergy, reward and action
    transition_rec = np.zeros((capm.eno.TIME_STEPS, N_STATES * 2 + 2)) #record all the transition in one day

    while True:
        a = dqn.choose_action(s)

        # present state = [batt, enp, henergy]
        record = np.vstack((record, [s[0],s[2],r, a])) # record battery, henergy, reward and action for troubleshooting
                                                       # However, we are interested only in the reward

        # take action
        s_, r, day_end, year_end = capm.step(a)

        temp_transitions = np.hstack((s, [a, r], s_))
        transition_rec[capm.eno.hr-1,:] = temp_transitions

        if (day_end):
            transition_rec[:,5] = r #broadcast reward to all states
            decay_factor = [i for i in (LAMBDA**n for n in reversed(range(0, capm.eno.TIME_STEPS)))]
            transition_rec[:,5] = transition_rec[:,5] * decay_factor #decay reward proportionately
            dqn.store_day_transition(transition_rec)

        if dqn.memory_counter > MEMORY_CAPACITY:
            dqn.learn()

        if (year_end):
    #             print("End of Year")
            break

        # transition to new state
        s = s_

    record = np.delete(record, 0, 0) #remove the first row which is garbage
    reward_rec = record[:,2] #extract reward information from the record array
    reward_rec = reward_rec[reward_rec != 0] #remove all zero rewards in the middle of the days
    print("Average Reward \t\t= {:8.3f}".format(np.mean(reward_rec)))

    # Check if reward beats the High Score and possible save it    
    if (iteration > 19): #save the best models only after 20 iterations
        print("Best Score \t = {:8.3f} @ Iteration No. {}".format(best_avg_reward, best_iteration))
        if(best_avg_reward < np.mean(reward_rec)):
            best_iteration = iteration
            best_avg_reward = np.mean(reward_rec)
            print("Saving Model")
            torch.save(dqn.eval_net.state_dict(), BFILENAME)
    else:
        print("\r")
    # Log the average reward in avg_reward_rec
    avg_reward_rec = np.append(avg_reward_rec, np.mean(reward_rec))

    # End of training
# Save the last model
torch.save(dqn.eval_net.state_dict(), TFILENAME) 

# Plot the average reward log
plt.plot(avg_reward_rec,'b')
plt.ylim([-3,1])
# Out:
# TRAINING IN PROGRESS
#
# Iteration 0:  MINAMIDAITO, 2008
# Average Reward 		=   -1.057
#
# Iteration 1:  TOKYO, 2009
# Average Reward 		=   -1.439
#
# Iteration 2:  TOKYO, 2009
# Average Reward 		=   -1.222
#
# Iteration 3:  WAKKANAI, 2005
# Average Reward 		=   -1.086
#
# Iteration 4:  TOKYO, 2007
# Average Reward 		=   -1.192
#
# Iteration 5:  TOKYO, 2009
# Average Reward 		=   -1.094
#
# Iteration 6:  MINAMIDAITO, 2010
# Average Reward 		=   -1.209
#
# Iteration 7:  TOKYO, 2010
# Average Reward 		=   -1.380
#
# Iteration 8:  MINAMIDAITO, 2007
# Average Reward 		=   -1.075
#
# Iteration 9:  WAKKANAI, 2005
# Average Reward 		=   -1.104
#
# Iteration 10:  MINAMIDAITO, 2005
# Average Reward 		=   -1.129
#
# Iteration 11:  TOKYO, 2012
# Average Reward 		=   -1.276
#
# Iteration 12:  WAKKANAI, 2007
# Average Reward 		=   -1.197
#
# Iteration 13:  WAKKANAI, 2011
# Average Reward 		=   -1.228
#
# Iteration 14:  TOKYO, 2008
# Average Reward 		=   -1.402
#
# Iteration 15:  MINAMIDAITO, 2010
# Average Reward 		=   -1.215
#
# Iteration 16:  MINAMIDAITO, 2010
# Average Reward 		=   -1.284
#
# Iteration 17:  MINAMIDAITO, 2014
# Average Reward 		=   -1.115
#
# Iteration 18:  MINAMIDAITO, 2006
# Average Reward 		=   -1.122
#
# Iteration 19:  WAKKANAI, 2014
# Average Reward 		=   -1.131
#
# Iteration 20:  WAKKANAI, 2005
# Average Reward 		=   -1.112
# Best Score 	 = -1000.000 @ Iteration No. -1
# Saving Model
# Iteration 21:  MINAMIDAITO, 2006
# Average Reward 		=   -1.120
# Best Score 	 =   -1.112 @ Iteration No. 20
# Iteration 22:  TOKYO, 2007
# Average Reward 		=   -1.244
# Best Score 	 =   -1.112 @ Iteration No. 20
# Iteration 23:  MINAMIDAITO, 2013
# Average Reward 		=   -1.096
# Best Score 	 =   -1.112 @ Iteration No. 20
# Saving Model
# Iteration 24:  MINAMIDAITO, 2007
# Average Reward 		=   -1.109
# Best Score 	 =   -1.096 @ Iteration No. 23
# Iteration 25:  TOKYO, 2006
# Average Reward 		=   -1.202
# Best Score 	 =   -1.096 @ Iteration No. 23
# Iteration 26:  TOKYO, 2013
# Average Reward 		=   -1.317
# Best Score 	 =   -1.096 @ Iteration No. 23
# Iteration 27:  TOKYO, 2005
# Average Reward 		=   -1.272
# Best Score 	 =   -1.096 @ Iteration No. 23
# Iteration 28:  WAKKANAI, 2014
# Average Reward 		=   -1.109
# Best Score 	 =   -1.096 @ Iteration No. 23
# Iteration 29:  WAKKANAI, 2013
# Average Reward 		=   -1.192
# Best Score 	 =   -1.096 @ Iteration No. 23
# Iteration 30:  MINAMIDAITO, 2011
# Average Reward 		=   -1.163
# Best Score 	 =   -1.096 @ Iteration No. 23
# Iteration 31:  WAKKANAI, 2013
# Average Reward 		=   -1.104
# Best Score 	 =   -1.096 @ Iteration No. 23
# Iteration 32:  WAKKANAI, 2013
# Average Reward 		=   -1.155
# Best Score 	 =   -1.096 @ Iteration No. 23
# Iteration 33:  MINAMIDAITO, 2006
# Average Reward 		=   -1.192
# Best Score 	 =   -1.096 @ Iteration No. 23
# Iteration 34:  TOKYO, 2006
# Average Reward 		=   -1.232
# Best Score 	 =   -1.096 @ Iteration No. 23
# Iteration 35:  MINAMIDAITO, 2010
# Average Reward 		=   -1.124
# Best Score 	 =   -1.096 @ Iteration No. 23
# Iteration 36:  TOKYO, 2009
# Average Reward 		=   -1.223
# Best Score 	 =   -1.096 @ Iteration No. 23
# Iteration 37:  WAKKANAI, 2012
# Average Reward 		=   -1.273
# Best Score 	 =   -1.096 @ Iteration No. 23
# Iteration 38:  MINAMIDAITO, 2013
# Average Reward 		=   -1.230
# Best Score 	 =   -1.096 @ Iteration No. 23
# Iteration 39:  MINAMIDAITO, 2005
# Average Reward 		=   -1.276
# Best Score 	 =   -1.096 @ Iteration No. 23
# Iteration 40:  WAKKANAI, 2005
# Average Reward 		=   -1.016
# Best Score 	 =   -1.096 @ Iteration No. 23
# Saving Model
# Iteration 41:  WAKKANAI, 2009
# Average Reward 		=   -1.213
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 42:  WAKKANAI, 2014
# Average Reward 		=   -1.296
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 43:  MINAMIDAITO, 2010
# Average Reward 		=   -1.155
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 44:  TOKYO, 2011
# Average Reward 		=   -1.258
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 45:  TOKYO, 2013
# Average Reward 		=   -1.214
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 46:  WAKKANAI, 2010
# Average Reward 		=   -1.200
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 47:  TOKYO, 2006
# Average Reward 		=   -1.267
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 48:  WAKKANAI, 2011
# Average Reward 		=   -1.179
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 49:  TOKYO, 2014
# Average Reward 		=   -1.220
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 50:  MINAMIDAITO, 2013
# Average Reward 		=   -1.302
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 51:  MINAMIDAITO, 2012
# Average Reward 		=   -1.337
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 52:  MINAMIDAITO, 2011
# Average Reward 		=   -1.245
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 53:  TOKYO, 2013
# Average Reward 		=   -1.110
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 54:  MINAMIDAITO, 2007
# Average Reward 		=   -1.195
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 55:  TOKYO, 2005
# Average Reward 		=   -1.337
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 56:  TOKYO, 2005
# Average Reward 		=   -1.138
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 57:  TOKYO, 2011
# Average Reward 		=   -1.192
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 58:  WAKKANAI, 2007
# Average Reward 		=   -1.245
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 59:  WAKKANAI, 2007
# Average Reward 		=   -1.283
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 60:  WAKKANAI, 2010
# Average Reward 		=   -1.366
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 61:  MINAMIDAITO, 2007
# Average Reward 		=   -1.161
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 62:  WAKKANAI, 2007
# Average Reward 		=   -1.425
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 63:  WAKKANAI, 2006
# Average Reward 		=   -1.188
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 64:  TOKYO, 2009
# Average Reward 		=   -1.305
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 65:  WAKKANAI, 2010
# Average Reward 		=   -1.245
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 66:  WAKKANAI, 2010
# Average Reward 		=   -1.129
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 67:  WAKKANAI, 2007
# Average Reward 		=   -1.264
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 68:  MINAMIDAITO, 2009
# Average Reward 		=   -1.167
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 69:  TOKYO, 2010
# Average Reward 		=   -1.257
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 70:  WAKKANAI, 2010
# Average Reward 		=   -1.185
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 71:  MINAMIDAITO, 2010
# Average Reward 		=   -1.306
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 72:  WAKKANAI, 2006
# Average Reward 		=   -1.319
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 73:  WAKKANAI, 2007
# Average Reward 		=   -1.094
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 74:  TOKYO, 2012
# Average Reward 		=   -1.084
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 75:  TOKYO, 2011
# Average Reward 		=   -1.267
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 76:  TOKYO, 2007
# Average Reward 		=   -1.311
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 77:  WAKKANAI, 2014
# Average Reward 		=   -1.271
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 78:  MINAMIDAITO, 2005
# Average Reward 		=   -1.234
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 79:  TOKYO, 2007
# Average Reward 		=   -1.372
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 80:  TOKYO, 2013
# Average Reward 		=   -1.186
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 81:  MINAMIDAITO, 2012
# Average Reward 		=   -1.278
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 82:  TOKYO, 2011
# Average Reward 		=   -1.137
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 83:  TOKYO, 2011
# Average Reward 		=   -1.323
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 84:  TOKYO, 2014
# Average Reward 		=   -1.225
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 85:  TOKYO, 2010
# Average Reward 		=   -1.236
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 86:  WAKKANAI, 2011
# Average Reward 		=   -1.129
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 87:  TOKYO, 2005
# Average Reward 		=   -1.260
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 88:  WAKKANAI, 2011
# Average Reward 		=   -1.047
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 89:  TOKYO, 2011
# Average Reward 		=   -1.122
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 90:  WAKKANAI, 2005
# Average Reward 		=   -1.186
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 91:  MINAMIDAITO, 2009
# Average Reward 		=   -1.120
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 92:  TOKYO, 2012
# Average Reward 		=   -1.257
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 93:  MINAMIDAITO, 2006
# Average Reward 		=   -1.351
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 94:  TOKYO, 2005
# Average Reward 		=   -1.071
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 95:  TOKYO, 2011
# Average Reward 		=   -1.156
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 96:  MINAMIDAITO, 2014
# Average Reward 		=   -1.246
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 97:  TOKYO, 2007
# Average Reward 		=   -1.260
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 98:  TOKYO, 2007
# Average Reward 		=   -1.186
# Best Score 	 =   -1.016 @ Iteration No. 40
# Iteration 99:  WAKKANAI, 2011
# Average Reward 		=   -1.226
# Best Score 	 =   -1.016 @ Iteration No. 40
# (-3, 1)

# %%
#BFILENAME -> loads the best model
#TFILENAME -> loads the last model
MODELFILE = BFILENAME
TEST_YEAR = '2018'
dqn = DQN()
for TEST_LOCATION in ['tokyo','wakkanai','minamidaito']:
    test_model(TEST_LOCATION, TEST_YEAR, MODELFILE, dqn)
# Out:
# Year run test (Greedy Policy)
# Model Used:  bestNSVST9FR.pt
# End of Test
# Average Reward for TOKYO,2018 = -2.818498468441938
# Year run test (Greedy Policy)
# Model Used:  bestNSVST9FR.pt
# End of Test
# Average Reward for WAKKANAI,2018 = -2.7177412090410558
# Year run test (Greedy Policy)
# Model Used:  bestNSVST9FR.pt
# End of Test
# Average Reward for MINAMIDAITO,2018 = -2.9450378740751306

# %%
MODELFILE = TFILENAME
TEST_YEAR = '2018'
dqn = DQN()
for TEST_LOCATION in ['tokyo','wakkanai','minamidaito']:
    test_model(TEST_LOCATION, TEST_YEAR, MODELFILE, dqn)
# Out:
# Year run test (Greedy Policy)
# Model Used:  terminalNSVST9FR.pt
# End of Test
# Average Reward for TOKYO,2018 = -2.818368870435297
# Year run test (Greedy Policy)
# Model Used:  terminalNSVST9FR.pt
# End of Test
# Average Reward for WAKKANAI,2018 = -2.7033281748672815
# Year run test (Greedy Policy)
# Model Used:  terminalNSVST9FR.pt
# End of Test
# Average Reward for MINAMIDAITO,2018 = -2.9450152049950384

# %%
# TEST_YEAR = 2018
# for TEST_LOCATION in ['tokyo','wakkanai','minamidaito']:
#     test_model(TEST_LOCATION, TEST_YEAR)

# %%
# dqn = DQN()
# capm = CAPM(TEST_LOCATION,TEST_YEAR, shuffle=False, trainmode=False) #if reset is True
# capm.eno = ENO(TEST_LOCATION,TEST_YEAR, shuffle=False, day_balance=False) #instantiate the environment inside the CAPM class
# capm.HMAX = capm.eno.SMAX #maximum power output of solar cell is set in CAPM object using the value in ENO object


# # load the required model
# dqn.eval_net.load_state_dict(torch.load(MODELFILE))
# dqn.eval_net.eval()
# print('Model Used: ',MODELFILE)

# s, r, day_end, year_end = capm.reset()
# yr_test_record = np.empty(4)

# while True:
#     a = dqn.choose_greedy_action(s)

#     #state = [batt, enp, henergy, fcast]
#     yr_test_record = np.vstack((yr_test_record, [s[0],s[2],r, a])) #record battery, henergy, reward and action

#     # take action
#     s_, r, day_end, year_end = capm.step(a)
    
# #     if day_end:
# #         if (capm.BMIN ==capm.batt or capm.batt == capm.BMAX):
# #             capm.batt = capm.BOPT
        

#     if year_end:
#         print("End of Test")
#         break

#     s = s_

# yr_test_record = np.delete(yr_test_record, 0, 0) #remove the first row which is garbage

# #Plot the reward and battery for the entire year run
# title = TEST_LOCATION.upper() + ',' + str(TEST_YEAR)

# NO_OF_DAYS = capm.eno.NO_OF_DAYS
# yr_test_reward_rec = yr_test_record[:,2]
# yr_test_reward_rec = yr_test_reward_rec[yr_test_reward_rec != 0]
# print('Average Reward for',title, '=', np.mean(yr_test_reward_rec))


# fig = plt.figure(figsize=(24,10))
# fig.suptitle(title, fontsize=15)

# #     ax1 = fig.add_subplot(211)
# #     ax1.plot(yr_test_reward_rec)
# #     ax1.set_title("\n\nYear Run Reward")
# #     ax1.set_ylim([-3,1])

# ax2 = fig.add_subplot(111)
# ax2.plot(yr_test_record[:,0],'r')
# ax2.set_title("\n\nYear Run Battery")
# ax2.set_ylim([0,1])
# plt.sca(ax2)
# plt.xticks(np.arange(0, NO_OF_DAYS*24, 50*24),np.arange(0,NO_OF_DAYS,50))

# fig.tight_layout()
# plt.show()

# %%
# #Plot the reward and battery for the entire year run on a day by day basis
# title = TEST_LOCATION.upper() + ',' + str(TEST_YEAR)
# TIME_AXIS = np.arange(0,capm.eno.TIME_STEPS)
# for DAY in range(150,170):#capm.eno.NO_OF_DAYS):
#     START = DAY*24
#     END = START+24

#     daytitle = title + ' - DAY ' + str(DAY)
#     fig = plt.figure(figsize=(16,4))
#     st = fig.suptitle(daytitle)

#     ax2 = fig.add_subplot(121)
#     ax2.plot(yr_test_record[START:END,1],'g')
#     ax2.set_title("HARVESTED ENERGY")
#     plt.xlabel("Hour")
#     ax2.set_ylim([0,1])

#     #plot battery for year run
#     ax1 = fig.add_subplot(122)
#     ax1.plot(TIME_AXIS,yr_test_record[START:END,0],'r') 
# #     ax1.plot(TIME_AXIS, np.ones(capm.eno.TIME_STEPS)*capm.BOPT/capm.BMAX,'r--')
#     ax1.plot(TIME_AXIS, np.ones(capm.eno.TIME_STEPS)*yr_test_record[START,0],'r--')
#     ax1.text(0.1, 0.2, "BINIT = %.2f\n" %(yr_test_record[START,0]),fontsize=11, ha='left')
#     ax1.text(0.1, 0.4, "TENP = %.2f\n" %(capm.BOPT/capm.BMAX-yr_test_record[END,0]),fontsize=11, ha='left')
#     ax1.text(0.1, 0.3, "BMEAN = %.2f\n" %(np.mean(yr_test_record[START:END,0])),fontsize=11, ha='left')



#     ax1.set_title("YEAR RUN TEST")
#     if END < (capm.eno.NO_OF_DAYS*capm.eno.TIME_STEPS):
#         ax1.text(0.1, 0, "REWARD = %.2f\n" %(yr_test_record[END,2]),fontsize=13, ha='left')
#     plt.xlabel("Hour")
#     ax1.set_ylabel('Battery', color='r',fontsize=12)
#     ax1.set_ylim([0,1])

#     #plot actions for year run
#     ax1a = ax1.twinx()
#     ax1a.plot(yr_test_record[START:END,3])
#     ax1a.set_ylim([0,N_ACTIONS])
#     ax1a.set_ylabel('Duty Cycle', color='b',fontsize=12)

#     fig.tight_layout()
#     st.set_y(0.95)
#     fig.subplots_adjust(top=0.75)
#     plt.show()
