# %%
# %matplotlib inline

from os.path import dirname, abspath, join
from os import getcwd
import sys

THIS_DIR = getcwd()
CLASS_DIR = abspath(join(THIS_DIR, '../../..', 'dsnclasses'))
sys.path.append(CLASS_DIR)

import random
import string
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from IPython.display import clear_output

from ENOnormal import ENO
from CAPMr3 import CAPM
from NN6a import DQN as DQN
from globalvar import *

# %%
def test_model(TEST_LOCATION, TEST_YEAR, MODELFILE, dqn):

    print('\nYear run test (Greedy Policy)')

#     dqn = DQN()
    capm = CAPM(TEST_LOCATION,TEST_YEAR, shuffle=False, trainmode=False) #if reset is True
    capm.eno = ENO(TEST_LOCATION,TEST_YEAR, shuffle=False, day_balance=False) #instantiate the environment inside the CAPM class
    capm.HMAX = capm.eno.SMAX #maximum power output of solar cell is set in CAPM object using the value in ENO object

    # load the required model
    dqn.eval_net.load_state_dict(torch.load(MODELFILE))
    dqn.eval_net.eval()
    print('Model Used: ',MODELFILE)

    s, r, day_end, year_end = capm.reset()
    yr_test_record = np.empty(4)

    while True:
        a = dqn.choose_greedy_action(s)

        #state = [batt, enp, henergy, fcast]
        yr_test_record = np.vstack((yr_test_record, [s[0],s[2],r, a])) #record battery, henergy, reward and action

        # take action
        s_, r, day_end, year_end = capm.step(a)

        if year_end:
            print("End of Test")
            break

        s = s_

    yr_test_record = np.delete(yr_test_record, 0, 0) #remove the first row which is garbage
    NO_OF_DAYS = capm.eno.NO_OF_DAYS
    yr_test_reward_rec = yr_test_record[:,2]
    yr_test_reward_rec = yr_test_reward_rec[yr_test_reward_rec != 0]
    
    #Plot the reward and battery for the entire year run
    title = TEST_LOCATION.upper() + ',' + str(TEST_YEAR)
    print('Average Reward for',title, '=', np.mean(yr_test_reward_rec))

    fig = plt.figure(figsize=(24,3))
    fig.suptitle(title, fontsize=15)

#     ax1 = fig.add_subplot(211)
#     ax1.plot(yr_test_reward_rec)
#     ax1.set_title("\n\nYear Run Reward")
#     ax1.set_ylim([-3,1])

    ax2 = fig.add_subplot(111)
    ax2.plot(yr_test_record[:,0],'r')
    ax2.set_title("\n\nYear Run Battery")
    ax2.set_ylim([0,1])
    plt.sca(ax2)
    plt.xticks(np.arange(0, NO_OF_DAYS*24, 50*24),np.arange(0,NO_OF_DAYS,50))

    fig.tight_layout()
    plt.show()    
    return 0

# %%
#TRAIN USING data from TOKYO, WAKKANAI and MINAMIDAITO FROM 2005 to 2014
dqn = DQN()

NO_OF_ITERATIONS = 100

best_iteration = -1
best_avg_reward = -1000 #initialize best average reward to very low value
PFILENAME = ''.join(random.choice(string.ascii_uppercase + string.digits) for _ in range(8)) #create random filename
BFILENAME = "best"+PFILENAME + ".pt" #this file stores the best model
TFILENAME = "terminal"+PFILENAME + ".pt" #this file stores the last model

avg_reward_rec = [] #record the yearly average rewards over the entire duration of training
print('\nTRAINING IN PROGRESS\n')

for iteration in range(NO_OF_ITERATIONS):
    LOCATION = random.choice(['tokyo','wakkanai','minamidaito'])
    YEAR = random.choice(np.arange(2005,2015))
    capm = CAPM(LOCATION,YEAR,shuffle=True, trainmode=True) #instantiate the CAPM class
    capm.eno = ENO(LOCATION,YEAR, shuffle=True, day_balance=True) #instantiate the environment inside the CAPM class
    capm.HMAX = capm.eno.SMAX #maximum power output of solar cell is set in CAPM object using the value in ENO object
    clear_output()
    print('Iteration {}:  {}, {} '.format(iteration, LOCATION.upper(), YEAR))

    s, r, day_end, year_end = capm.reset()
    record = np.empty(4) #record for battery, henergy, reward and action
    transition_rec = np.zeros((capm.eno.TIME_STEPS, N_STATES * 2 + 2)) #record all the transition in one day

    while True:
        a = dqn.choose_action(s)

        # present state = [batt, enp, henergy]
        record = np.vstack((record, [s[0],s[2],r, a])) # record battery, henergy, reward and action for troubleshooting
                                                       # However, we are interested only in the reward

        # take action
        s_, r, day_end, year_end = capm.step(a)

        temp_transitions = np.hstack((s, [a, r], s_))
        transition_rec[capm.eno.hr-1,:] = temp_transitions

        if (day_end):
            transition_rec[:,5] = r #broadcast reward to all states
            decay_factor = [i for i in (LAMBDA**n for n in reversed(range(0, capm.eno.TIME_STEPS)))]
            transition_rec[:,5] = transition_rec[:,5] * decay_factor #decay reward proportionately
            dqn.store_day_transition(transition_rec)

        if dqn.memory_counter > MEMORY_CAPACITY:
            dqn.learn()

        if (year_end):
    #             print("End of Year")
            break

        # transition to new state
        s = s_

    record = np.delete(record, 0, 0) #remove the first row which is garbage
    reward_rec = record[:,2] #extract reward information from the record array
    reward_rec = reward_rec[reward_rec != 0] #remove all zero rewards in the middle of the days
    print("Average Reward \t\t= {:8.3f}".format(np.mean(reward_rec)))

    # Check if reward beats the High Score and possible save it    
    if (iteration > 19): #save the best models only after 20 iterations
        print("Best Score \t = {:8.3f} @ Iteration No. {}".format(best_avg_reward, best_iteration))
        if(best_avg_reward < np.mean(reward_rec)):
            best_iteration = iteration
            best_avg_reward = np.mean(reward_rec)
            print("Saving Model")
            torch.save(dqn.eval_net.state_dict(), BFILENAME)
    else:
        print("\r")
    # Log the average reward in avg_reward_rec
    avg_reward_rec = np.append(avg_reward_rec, np.mean(reward_rec))

    # End of training
# Save the last model
torch.save(dqn.eval_net.state_dict(), TFILENAME) 

# Plot the average reward log
plt.plot(avg_reward_rec,'b')
plt.ylim([-3,1])
# Out:
# TRAINING IN PROGRESS
#
# Iteration 0:  TOKYO, 2013
# Average Reward 		=   -1.321
#
# Iteration 1:  WAKKANAI, 2008
# Average Reward 		=   -0.247
#
# Iteration 2:  WAKKANAI, 2012
# Average Reward 		=   -0.076
#
# Iteration 3:  WAKKANAI, 2010
# Average Reward 		=   -0.498
#
# Iteration 4:  MINAMIDAITO, 2014
# Average Reward 		=   -0.016
#
# Iteration 5:  WAKKANAI, 2006
# Average Reward 		=    0.481
#
# Iteration 6:  MINAMIDAITO, 2013
# Average Reward 		=   -0.198
#
# Iteration 7:  TOKYO, 2006
# Average Reward 		=   -0.263
#
# Iteration 8:  TOKYO, 2009
# Average Reward 		=   -0.042
#
# Iteration 9:  TOKYO, 2010
# Average Reward 		=   -0.222
#
# Iteration 10:  WAKKANAI, 2008
# Average Reward 		=   -0.732
#
# Iteration 11:  MINAMIDAITO, 2014
# Average Reward 		=   -0.441
#
# Iteration 12:  MINAMIDAITO, 2007
# Average Reward 		=    0.047
#
# Iteration 13:  TOKYO, 2013
# Average Reward 		=   -0.363
#
# Iteration 14:  TOKYO, 2005
# Average Reward 		=   -0.549
#
# Iteration 15:  WAKKANAI, 2008
# Average Reward 		=   -0.395
#
# Iteration 16:  TOKYO, 2012
# Average Reward 		=   -0.054
#
# Iteration 17:  TOKYO, 2011
# Average Reward 		=    0.588
#
# Iteration 18:  TOKYO, 2008
# Average Reward 		=    0.014
#
# Iteration 19:  WAKKANAI, 2006
# Average Reward 		=    0.010
#
# Iteration 20:  WAKKANAI, 2011
# Average Reward 		=    0.222
# Best Score 	 = -1000.000 @ Iteration No. -1
# Saving Model
# Iteration 21:  MINAMIDAITO, 2011
# Average Reward 		=    0.152
# Best Score 	 =    0.222 @ Iteration No. 20
# Iteration 22:  MINAMIDAITO, 2013
# Average Reward 		=   -0.727
# Best Score 	 =    0.222 @ Iteration No. 20
# Iteration 23:  MINAMIDAITO, 2010
# Average Reward 		=   -0.980
# Best Score 	 =    0.222 @ Iteration No. 20
# Iteration 24:  MINAMIDAITO, 2011
# Average Reward 		=   -0.642
# Best Score 	 =    0.222 @ Iteration No. 20
# Iteration 25:  TOKYO, 2007
# Average Reward 		=   -0.999
# Best Score 	 =    0.222 @ Iteration No. 20
# Iteration 26:  WAKKANAI, 2006
# Average Reward 		=    0.056
# Best Score 	 =    0.222 @ Iteration No. 20
# Iteration 27:  TOKYO, 2012
# Average Reward 		=    0.122
# Best Score 	 =    0.222 @ Iteration No. 20
# Iteration 28:  TOKYO, 2005
# Average Reward 		=   -1.636
# Best Score 	 =    0.222 @ Iteration No. 20
# Iteration 29:  WAKKANAI, 2014
# Average Reward 		=   -0.803
# Best Score 	 =    0.222 @ Iteration No. 20
# Iteration 30:  MINAMIDAITO, 2013
# Average Reward 		=   -0.370
# Best Score 	 =    0.222 @ Iteration No. 20
# Iteration 31:  WAKKANAI, 2007
# Average Reward 		=   -0.997
# Best Score 	 =    0.222 @ Iteration No. 20
# Iteration 32:  MINAMIDAITO, 2013
# Average Reward 		=   -0.790
# Best Score 	 =    0.222 @ Iteration No. 20
# Iteration 33:  WAKKANAI, 2005
# Average Reward 		=   -1.388
# Best Score 	 =    0.222 @ Iteration No. 20
# Iteration 34:  MINAMIDAITO, 2010
# Average Reward 		=    0.195
# Best Score 	 =    0.222 @ Iteration No. 20
# Iteration 35:  TOKYO, 2010
# Average Reward 		=    0.094
# Best Score 	 =    0.222 @ Iteration No. 20
# Iteration 36:  WAKKANAI, 2005
# Average Reward 		=   -1.137
# Best Score 	 =    0.222 @ Iteration No. 20
# Iteration 37:  TOKYO, 2012
# Average Reward 		=   -1.373
# Best Score 	 =    0.222 @ Iteration No. 20
# Iteration 38:  MINAMIDAITO, 2006
# Average Reward 		=   -0.873
# Best Score 	 =    0.222 @ Iteration No. 20
# Iteration 39:  WAKKANAI, 2008
# Average Reward 		=   -1.027
# Best Score 	 =    0.222 @ Iteration No. 20
# Iteration 40:  WAKKANAI, 2008
# Average Reward 		=   -0.318
# Best Score 	 =    0.222 @ Iteration No. 20
# Iteration 41:  WAKKANAI, 2009
# Average Reward 		=   -0.854
# Best Score 	 =    0.222 @ Iteration No. 20
# Iteration 42:  MINAMIDAITO, 2013
# Average Reward 		=   -1.154
# Best Score 	 =    0.222 @ Iteration No. 20
# Iteration 43:  WAKKANAI, 2006
# Average Reward 		=   -0.184
# Best Score 	 =    0.222 @ Iteration No. 20
# Iteration 44:  MINAMIDAITO, 2013
# Average Reward 		=   -0.277
# Best Score 	 =    0.222 @ Iteration No. 20
# Iteration 45:  TOKYO, 2010
# Average Reward 		=   -0.740
# Best Score 	 =    0.222 @ Iteration No. 20
# Iteration 46:  WAKKANAI, 2011
# Average Reward 		=   -0.716
# Best Score 	 =    0.222 @ Iteration No. 20
# Iteration 47:  TOKYO, 2007
# Average Reward 		=   -0.842
# Best Score 	 =    0.222 @ Iteration No. 20
# Iteration 48:  WAKKANAI, 2006
# Average Reward 		=   -0.891
# Best Score 	 =    0.222 @ Iteration No. 20
# Iteration 49:  WAKKANAI, 2014
# Average Reward 		=    0.161
# Best Score 	 =    0.222 @ Iteration No. 20
# Iteration 50:  TOKYO, 2007
# Average Reward 		=    0.445
# Best Score 	 =    0.222 @ Iteration No. 20
# Saving Model
# Iteration 51:  TOKYO, 2007
# Average Reward 		=   -0.828
# Best Score 	 =    0.445 @ Iteration No. 50
# Iteration 52:  TOKYO, 2009
# Average Reward 		=   -1.546
# Best Score 	 =    0.445 @ Iteration No. 50
# Iteration 53:  MINAMIDAITO, 2005
# Average Reward 		=   -1.055
# Best Score 	 =    0.445 @ Iteration No. 50
# Iteration 54:  WAKKANAI, 2010
# Average Reward 		=   -1.040
# Best Score 	 =    0.445 @ Iteration No. 50
# Iteration 55:  TOKYO, 2009
# Average Reward 		=   -1.256
# Best Score 	 =    0.445 @ Iteration No. 50
# Iteration 56:  WAKKANAI, 2006
# Average Reward 		=   -1.107
# Best Score 	 =    0.445 @ Iteration No. 50
# Iteration 57:  TOKYO, 2006
# Average Reward 		=   -1.058
# Best Score 	 =    0.445 @ Iteration No. 50
# Iteration 58:  WAKKANAI, 2010
# Average Reward 		=   -1.054
# Best Score 	 =    0.445 @ Iteration No. 50
# Iteration 59:  WAKKANAI, 2012
# Average Reward 		=   -1.476
# Best Score 	 =    0.445 @ Iteration No. 50
# Iteration 60:  MINAMIDAITO, 2013
# Average Reward 		=   -1.189
# Best Score 	 =    0.445 @ Iteration No. 50
# Iteration 61:  TOKYO, 2008
# Average Reward 		=   -1.078
# Best Score 	 =    0.445 @ Iteration No. 50
# Iteration 62:  WAKKANAI, 2009
# Average Reward 		=   -1.243
# Best Score 	 =    0.445 @ Iteration No. 50
# Iteration 63:  WAKKANAI, 2010
# Average Reward 		=   -1.298
# Best Score 	 =    0.445 @ Iteration No. 50
# Iteration 64:  MINAMIDAITO, 2012
# Average Reward 		=   -1.216
# Best Score 	 =    0.445 @ Iteration No. 50
# Iteration 65:  TOKYO, 2005
# Average Reward 		=   -1.406
# Best Score 	 =    0.445 @ Iteration No. 50
# Iteration 66:  TOKYO, 2014
# Average Reward 		=   -1.366
# Best Score 	 =    0.445 @ Iteration No. 50
# Iteration 67:  TOKYO, 2006
# Average Reward 		=   -1.344
# Best Score 	 =    0.445 @ Iteration No. 50
# Iteration 68:  MINAMIDAITO, 2011
# Average Reward 		=   -0.240
# Best Score 	 =    0.445 @ Iteration No. 50
# Iteration 69:  WAKKANAI, 2012
# Average Reward 		=   -0.202
# Best Score 	 =    0.445 @ Iteration No. 50
# Iteration 70:  TOKYO, 2011
# Average Reward 		=   -0.426
# Best Score 	 =    0.445 @ Iteration No. 50
# Iteration 71:  WAKKANAI, 2010
# Average Reward 		=   -0.355
# Best Score 	 =    0.445 @ Iteration No. 50
# Iteration 72:  MINAMIDAITO, 2014
# Average Reward 		=   -0.504
# Best Score 	 =    0.445 @ Iteration No. 50
# Iteration 73:  WAKKANAI, 2013
# Average Reward 		=   -0.456
# Best Score 	 =    0.445 @ Iteration No. 50
# Iteration 74:  WAKKANAI, 2005
# Average Reward 		=   -0.503
# Best Score 	 =    0.445 @ Iteration No. 50
# Iteration 75:  MINAMIDAITO, 2012
# Average Reward 		=   -0.482
# Best Score 	 =    0.445 @ Iteration No. 50
# Iteration 76:  WAKKANAI, 2011
# Average Reward 		=   -0.476
# Best Score 	 =    0.445 @ Iteration No. 50
# Iteration 77:  MINAMIDAITO, 2012
# Average Reward 		=   -0.535
# Best Score 	 =    0.445 @ Iteration No. 50
# Iteration 78:  TOKYO, 2012
# Average Reward 		=   -0.343
# Best Score 	 =    0.445 @ Iteration No. 50
# Iteration 79:  MINAMIDAITO, 2011
# Average Reward 		=   -0.454
# Best Score 	 =    0.445 @ Iteration No. 50
# Iteration 80:  WAKKANAI, 2011
# Average Reward 		=   -0.499
# Best Score 	 =    0.445 @ Iteration No. 50
# Iteration 81:  WAKKANAI, 2014
# Average Reward 		=   -0.356
# Best Score 	 =    0.445 @ Iteration No. 50
# Iteration 82:  TOKYO, 2011
# Average Reward 		=   -0.290
# Best Score 	 =    0.445 @ Iteration No. 50
# Iteration 83:  TOKYO, 2007
# Average Reward 		=   -0.563
# Best Score 	 =    0.445 @ Iteration No. 50
# Iteration 84:  MINAMIDAITO, 2014
# Average Reward 		=   -0.441
# Best Score 	 =    0.445 @ Iteration No. 50
# Iteration 85:  TOKYO, 2005
# Average Reward 		=    0.281
# Best Score 	 =    0.445 @ Iteration No. 50
# Iteration 86:  MINAMIDAITO, 2009
# Average Reward 		=   -0.967
# Best Score 	 =    0.445 @ Iteration No. 50
# Iteration 87:  WAKKANAI, 2005
# Average Reward 		=   -1.298
# Best Score 	 =    0.445 @ Iteration No. 50
# Iteration 88:  TOKYO, 2006
# Average Reward 		=   -1.347
# Best Score 	 =    0.445 @ Iteration No. 50
# Iteration 89:  WAKKANAI, 2014
# Average Reward 		=   -1.255
# Best Score 	 =    0.445 @ Iteration No. 50
# Iteration 90:  MINAMIDAITO, 2008
# Average Reward 		=   -1.448
# Best Score 	 =    0.445 @ Iteration No. 50
# Iteration 91:  WAKKANAI, 2006
# Average Reward 		=   -1.344
# Best Score 	 =    0.445 @ Iteration No. 50
# Iteration 92:  MINAMIDAITO, 2008
# Average Reward 		=   -1.201
# Best Score 	 =    0.445 @ Iteration No. 50
# Iteration 93:  MINAMIDAITO, 2011
# Average Reward 		=   -1.267
# Best Score 	 =    0.445 @ Iteration No. 50
# Iteration 94:  WAKKANAI, 2014
# Average Reward 		=   -1.172
# Best Score 	 =    0.445 @ Iteration No. 50
# Iteration 95:  WAKKANAI, 2012
# Average Reward 		=   -1.214
# Best Score 	 =    0.445 @ Iteration No. 50
# Iteration 96:  TOKYO, 2007
# Average Reward 		=   -1.283
# Best Score 	 =    0.445 @ Iteration No. 50
# Iteration 97:  TOKYO, 2009
# Average Reward 		=   -1.323
# Best Score 	 =    0.445 @ Iteration No. 50
# Iteration 98:  MINAMIDAITO, 2014
# Average Reward 		=   -1.311
# Best Score 	 =    0.445 @ Iteration No. 50
# Iteration 99:  TOKYO, 2014
# Average Reward 		=   -1.267
# Best Score 	 =    0.445 @ Iteration No. 50
# (-3, 1)

# %%
#BFILENAME -> loads the best model
#TFILENAME -> loads the last model
MODELFILE = BFILENAME
TEST_YEAR = '2018'
dqn = DQN()
for TEST_LOCATION in ['tokyo','wakkanai','minamidaito']:
    test_model(TEST_LOCATION, TEST_YEAR, MODELFILE, dqn)
# Out:
# Year run test (Greedy Policy)
# Model Used:  best691QD2KG.pt
# End of Test
# Average Reward for TOKYO,2018 = 1.8257554476584945
# Year run test (Greedy Policy)
# Model Used:  best691QD2KG.pt
# End of Test
# Average Reward for WAKKANAI,2018 = 1.4024351288937933
# Year run test (Greedy Policy)
# Model Used:  best691QD2KG.pt
# End of Test
# Average Reward for MINAMIDAITO,2018 = 1.7381577271985338

# %%
MODELFILE = TFILENAME
TEST_YEAR = '2018'
dqn = DQN()
for TEST_LOCATION in ['tokyo','wakkanai','minamidaito']:
    test_model(TEST_LOCATION, TEST_YEAR, MODELFILE, dqn)
# Out:
# Year run test (Greedy Policy)
# Model Used:  terminal691QD2KG.pt
# End of Test
# Average Reward for TOKYO,2018 = -2.784161392206254
# Year run test (Greedy Policy)
# Model Used:  terminal691QD2KG.pt
# End of Test
# Average Reward for WAKKANAI,2018 = -2.7965418894586995
# Year run test (Greedy Policy)
# Model Used:  terminal691QD2KG.pt
# End of Test
# Average Reward for MINAMIDAITO,2018 = -2.5903617897325444

# %%
# TEST_YEAR = 2018
# for TEST_LOCATION in ['tokyo','wakkanai','minamidaito']:
#     test_model(TEST_LOCATION, TEST_YEAR)

# %%
# dqn = DQN()
# capm = CAPM(TEST_LOCATION,TEST_YEAR, shuffle=False, trainmode=False) #if reset is True
# capm.eno = ENO(TEST_LOCATION,TEST_YEAR, shuffle=False, day_balance=False) #instantiate the environment inside the CAPM class
# capm.HMAX = capm.eno.SMAX #maximum power output of solar cell is set in CAPM object using the value in ENO object


# # load the required model
# dqn.eval_net.load_state_dict(torch.load(MODELFILE))
# dqn.eval_net.eval()
# print('Model Used: ',MODELFILE)

# s, r, day_end, year_end = capm.reset()
# yr_test_record = np.empty(4)

# while True:
#     a = dqn.choose_greedy_action(s)

#     #state = [batt, enp, henergy, fcast]
#     yr_test_record = np.vstack((yr_test_record, [s[0],s[2],r, a])) #record battery, henergy, reward and action

#     # take action
#     s_, r, day_end, year_end = capm.step(a)
    
# #     if day_end:
# #         if (capm.BMIN ==capm.batt or capm.batt == capm.BMAX):
# #             capm.batt = capm.BOPT
        

#     if year_end:
#         print("End of Test")
#         break

#     s = s_

# yr_test_record = np.delete(yr_test_record, 0, 0) #remove the first row which is garbage

# #Plot the reward and battery for the entire year run
# title = TEST_LOCATION.upper() + ',' + str(TEST_YEAR)

# NO_OF_DAYS = capm.eno.NO_OF_DAYS
# yr_test_reward_rec = yr_test_record[:,2]
# yr_test_reward_rec = yr_test_reward_rec[yr_test_reward_rec != 0]
# print('Average Reward for',title, '=', np.mean(yr_test_reward_rec))


# fig = plt.figure(figsize=(24,10))
# fig.suptitle(title, fontsize=15)

# #     ax1 = fig.add_subplot(211)
# #     ax1.plot(yr_test_reward_rec)
# #     ax1.set_title("\n\nYear Run Reward")
# #     ax1.set_ylim([-3,1])

# ax2 = fig.add_subplot(111)
# ax2.plot(yr_test_record[:,0],'r')
# ax2.set_title("\n\nYear Run Battery")
# ax2.set_ylim([0,1])
# plt.sca(ax2)
# plt.xticks(np.arange(0, NO_OF_DAYS*24, 50*24),np.arange(0,NO_OF_DAYS,50))

# fig.tight_layout()
# plt.show()

# %%
# #Plot the reward and battery for the entire year run on a day by day basis
# title = TEST_LOCATION.upper() + ',' + str(TEST_YEAR)
# TIME_AXIS = np.arange(0,capm.eno.TIME_STEPS)
# for DAY in range(150,170):#capm.eno.NO_OF_DAYS):
#     START = DAY*24
#     END = START+24

#     daytitle = title + ' - DAY ' + str(DAY)
#     fig = plt.figure(figsize=(16,4))
#     st = fig.suptitle(daytitle)

#     ax2 = fig.add_subplot(121)
#     ax2.plot(yr_test_record[START:END,1],'g')
#     ax2.set_title("HARVESTED ENERGY")
#     plt.xlabel("Hour")
#     ax2.set_ylim([0,1])

#     #plot battery for year run
#     ax1 = fig.add_subplot(122)
#     ax1.plot(TIME_AXIS,yr_test_record[START:END,0],'r') 
# #     ax1.plot(TIME_AXIS, np.ones(capm.eno.TIME_STEPS)*capm.BOPT/capm.BMAX,'r--')
#     ax1.plot(TIME_AXIS, np.ones(capm.eno.TIME_STEPS)*yr_test_record[START,0],'r--')
#     ax1.text(0.1, 0.2, "BINIT = %.2f\n" %(yr_test_record[START,0]),fontsize=11, ha='left')
#     ax1.text(0.1, 0.4, "TENP = %.2f\n" %(capm.BOPT/capm.BMAX-yr_test_record[END,0]),fontsize=11, ha='left')
#     ax1.text(0.1, 0.3, "BMEAN = %.2f\n" %(np.mean(yr_test_record[START:END,0])),fontsize=11, ha='left')



#     ax1.set_title("YEAR RUN TEST")
#     if END < (capm.eno.NO_OF_DAYS*capm.eno.TIME_STEPS):
#         ax1.text(0.1, 0, "REWARD = %.2f\n" %(yr_test_record[END,2]),fontsize=13, ha='left')
#     plt.xlabel("Hour")
#     ax1.set_ylabel('Battery', color='r',fontsize=12)
#     ax1.set_ylim([0,1])

#     #plot actions for year run
#     ax1a = ax1.twinx()
#     ax1a.plot(yr_test_record[START:END,3])
#     ax1a.set_ylim([0,N_ACTIONS])
#     ax1a.set_ylabel('Duty Cycle', color='b',fontsize=12)

#     fig.tight_layout()
#     st.set_y(0.95)
#     fig.subplots_adjust(top=0.75)
#     plt.show()
