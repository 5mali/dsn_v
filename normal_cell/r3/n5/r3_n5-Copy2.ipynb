# %%
# %matplotlib inline

from os.path import dirname, abspath, join
from os import getcwd
import sys

THIS_DIR = getcwd()
CLASS_DIR = abspath(join(THIS_DIR, '../../..', 'dsnclasses'))
sys.path.append(CLASS_DIR)

import random
import string
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from IPython.display import clear_output

from ENOnormal import ENO
from CAPMr3 import CAPM
from NN5 import DQN as DQN
from globalvar import *

# %%
def test_model(TEST_LOCATION, TEST_YEAR, MODELFILE, dqn):

    print('\nYear run test (Greedy Policy)')

#     dqn = DQN()
    capm = CAPM(TEST_LOCATION,TEST_YEAR, shuffle=False, trainmode=False) #if reset is True
    capm.eno = ENO(TEST_LOCATION,TEST_YEAR, shuffle=False, day_balance=False) #instantiate the environment inside the CAPM class
    capm.HMAX = capm.eno.SMAX #maximum power output of solar cell is set in CAPM object using the value in ENO object

    # load the required model
    dqn.eval_net.load_state_dict(torch.load(MODELFILE))
    dqn.eval_net.eval()
    print('Model Used: ',MODELFILE)

    s, r, day_end, year_end = capm.reset()
    yr_test_record = np.empty(4)

    while True:
        a = dqn.choose_greedy_action(s)

        #state = [batt, enp, henergy, fcast]
        yr_test_record = np.vstack((yr_test_record, [s[0],s[2],r, a])) #record battery, henergy, reward and action

        # take action
        s_, r, day_end, year_end = capm.step(a)

        if year_end:
            print("End of Test")
            break

        s = s_

    yr_test_record = np.delete(yr_test_record, 0, 0) #remove the first row which is garbage
    NO_OF_DAYS = capm.eno.NO_OF_DAYS
    yr_test_reward_rec = yr_test_record[:,2]
    yr_test_reward_rec = yr_test_reward_rec[yr_test_reward_rec != 0]
    
    #Plot the reward and battery for the entire year run
    title = TEST_LOCATION.upper() + ',' + str(TEST_YEAR)
    print('Average Reward for',title, '=', np.mean(yr_test_reward_rec))

    fig = plt.figure(figsize=(24,3))
    fig.suptitle(title, fontsize=15)

#     ax1 = fig.add_subplot(211)
#     ax1.plot(yr_test_reward_rec)
#     ax1.set_title("\n\nYear Run Reward")
#     ax1.set_ylim([-3,1])

    ax2 = fig.add_subplot(111)
    ax2.plot(yr_test_record[:,0],'r')
    ax2.set_title("\n\nYear Run Battery")
    ax2.set_ylim([0,1])
    plt.sca(ax2)
    plt.xticks(np.arange(0, NO_OF_DAYS*24, 50*24),np.arange(0,NO_OF_DAYS,50))

    fig.tight_layout()
    plt.show()    
    return 0

# %%
#TRAIN USING data from TOKYO, WAKKANAI and MINAMIDAITO FROM 2005 to 2014
dqn = DQN()

NO_OF_ITERATIONS = 100

best_iteration = -1
best_avg_reward = -1000 #initialize best average reward to very low value
PFILENAME = ''.join(random.choice(string.ascii_uppercase + string.digits) for _ in range(8)) #create random filename
BFILENAME = "best"+PFILENAME + ".pt" #this file stores the best model
TFILENAME = "terminal"+PFILENAME + ".pt" #this file stores the last model

avg_reward_rec = [] #record the yearly average rewards over the entire duration of training
print('\nTRAINING IN PROGRESS\n')

for iteration in range(NO_OF_ITERATIONS):
    LOCATION = random.choice(['tokyo','wakkanai','minamidaito'])
    YEAR = random.choice(np.arange(2005,2015))
    capm = CAPM(LOCATION,YEAR,shuffle=True, trainmode=True) #instantiate the CAPM class
    capm.eno = ENO(LOCATION,YEAR, shuffle=True, day_balance=True) #instantiate the environment inside the CAPM class
    capm.HMAX = capm.eno.SMAX #maximum power output of solar cell is set in CAPM object using the value in ENO object
#     clear_output()
    print('Iteration {}:  {}, {} '.format(iteration, LOCATION.upper(), YEAR))

    s, r, day_end, year_end = capm.reset()
    record = np.empty(4) #record for battery, henergy, reward and action
    transition_rec = np.zeros((capm.eno.TIME_STEPS, N_STATES * 2 + 2)) #record all the transition in one day

    while True:
        a = dqn.choose_action(s)

        # present state = [batt, enp, henergy]
        record = np.vstack((record, [s[0],s[2],r, a])) # record battery, henergy, reward and action for troubleshooting
                                                       # However, we are interested only in the reward

        # take action
        s_, r, day_end, year_end = capm.step(a)

        temp_transitions = np.hstack((s, [a, r], s_))
        transition_rec[capm.eno.hr-1,:] = temp_transitions

        if (day_end):
            transition_rec[:,5] = r #broadcast reward to all states
            decay_factor = [i for i in (LAMBDA**n for n in reversed(range(0, capm.eno.TIME_STEPS)))]
            transition_rec[:,5] = transition_rec[:,5] * decay_factor #decay reward proportionately
            dqn.store_day_transition(transition_rec)

        if dqn.memory_counter > MEMORY_CAPACITY:
            dqn.learn()

        if (year_end):
    #             print("End of Year")
            break

        # transition to new state
        s = s_

    record = np.delete(record, 0, 0) #remove the first row which is garbage
    reward_rec = record[:,2] #extract reward information from the record array
    reward_rec = reward_rec[reward_rec != 0] #remove all zero rewards in the middle of the days
    print("Average Reward \t\t= {:8.3f}".format(np.mean(reward_rec)))

    # Check if reward beats the High Score and possible save it    
    if (iteration > 19): #save the best models only after 20 iterations
        print("Best Score \t = {:8.3f} @ Iteration No. {}".format(best_avg_reward, best_iteration))
        if(best_avg_reward < np.mean(reward_rec)):
            best_iteration = iteration
            best_avg_reward = np.mean(reward_rec)
            print("Saving Model")
            torch.save(dqn.eval_net.state_dict(), BFILENAME)
    else:
        print("\r")
    # Log the average reward in avg_reward_rec
    avg_reward_rec = np.append(avg_reward_rec, np.mean(reward_rec))

    # End of training
# Save the last model
torch.save(dqn.eval_net.state_dict(), TFILENAME) 

# Plot the average reward log
plt.plot(avg_reward_rec,'b')
plt.ylim([-3,1])
# Out:
# TRAINING IN PROGRESS
#
# Iteration 0:  WAKKANAI, 2008
# Average Reward 		=   -0.279
#
# Iteration 1:  TOKYO, 2013
# Average Reward 		=    0.084
#
# Iteration 2:  WAKKANAI, 2014
# Average Reward 		=    0.160
#
# Iteration 3:  WAKKANAI, 2012
# Average Reward 		=   -0.208
#
# Iteration 4:  WAKKANAI, 2005
# Average Reward 		=   -0.130
#
# Iteration 5:  MINAMIDAITO, 2007
# Average Reward 		=   -0.076
#
# Iteration 6:  MINAMIDAITO, 2014
# Average Reward 		=   -0.048
#
# Iteration 7:  WAKKANAI, 2005
# Average Reward 		=    0.285
#
# Iteration 8:  MINAMIDAITO, 2008
# Average Reward 		=    0.140
#
# Iteration 9:  WAKKANAI, 2009
# Average Reward 		=   -0.749
#
# Iteration 10:  TOKYO, 2006
# Average Reward 		=    0.068
#
# Iteration 11:  WAKKANAI, 2010
# Average Reward 		=    0.108
#
# Iteration 12:  TOKYO, 2006
# Average Reward 		=   -0.205
#
# Iteration 13:  MINAMIDAITO, 2007
# Average Reward 		=   -0.245
#
# Iteration 14:  WAKKANAI, 2009
# Average Reward 		=    0.351
#
# Iteration 15:  TOKYO, 2010
# Average Reward 		=   -0.188
#
# Iteration 16:  WAKKANAI, 2005
# Average Reward 		=   -0.347
#
# Iteration 17:  MINAMIDAITO, 2010
# Average Reward 		=    0.102
#
# Iteration 18:  MINAMIDAITO, 2014
# Average Reward 		=   -0.271
#
# Iteration 19:  MINAMIDAITO, 2012
# Average Reward 		=   -0.966
#
# Iteration 20:  MINAMIDAITO, 2009
# Average Reward 		=   -0.045
# Best Score 	 = -1000.000 @ Iteration No. -1
# Saving Model
# Iteration 21:  TOKYO, 2008
# Average Reward 		=   -0.372
# Best Score 	 =   -0.045 @ Iteration No. 20
# Iteration 22:  WAKKANAI, 2005
# Average Reward 		=    0.177
# Best Score 	 =   -0.045 @ Iteration No. 20
# Saving Model
# Iteration 23:  WAKKANAI, 2013
# Average Reward 		=    0.136
# Best Score 	 =    0.177 @ Iteration No. 22
# Iteration 24:  TOKYO, 2007
# Average Reward 		=    0.078
# Best Score 	 =    0.177 @ Iteration No. 22
# Iteration 25:  WAKKANAI, 2005
# Average Reward 		=   -0.923
# Best Score 	 =    0.177 @ Iteration No. 22
# Iteration 26:  MINAMIDAITO, 2014
# Average Reward 		=   -0.386
# Best Score 	 =    0.177 @ Iteration No. 22
# Iteration 27:  WAKKANAI, 2013
# Average Reward 		=    0.106
# Best Score 	 =    0.177 @ Iteration No. 22
# Iteration 28:  WAKKANAI, 2008
# Average Reward 		=   -1.198
# Best Score 	 =    0.177 @ Iteration No. 22
# Iteration 29:  TOKYO, 2013
# Average Reward 		=   -0.327
# Best Score 	 =    0.177 @ Iteration No. 22
# Iteration 30:  WAKKANAI, 2009
# Average Reward 		=    0.292
# Best Score 	 =    0.177 @ Iteration No. 22
# Saving Model
# Iteration 31:  TOKYO, 2010
# Average Reward 		=   -0.012
# Best Score 	 =    0.292 @ Iteration No. 30
# Iteration 32:  WAKKANAI, 2010
# Average Reward 		=   -0.842
# Best Score 	 =    0.292 @ Iteration No. 30
# Iteration 33:  WAKKANAI, 2006
# Average Reward 		=   -0.413
# Best Score 	 =    0.292 @ Iteration No. 30
# Iteration 34:  WAKKANAI, 2012
# Average Reward 		=   -1.267
# Best Score 	 =    0.292 @ Iteration No. 30
# Iteration 35:  WAKKANAI, 2013
# Average Reward 		=   -1.116
# Best Score 	 =    0.292 @ Iteration No. 30
# Iteration 36:  TOKYO, 2007
# Average Reward 		=   -0.341
# Best Score 	 =    0.292 @ Iteration No. 30
# Iteration 37:  WAKKANAI, 2014
# Average Reward 		=    0.416
# Best Score 	 =    0.292 @ Iteration No. 30
# Saving Model
# Iteration 38:  MINAMIDAITO, 2013
# Average Reward 		=    0.028
# Best Score 	 =    0.416 @ Iteration No. 37
# Iteration 39:  MINAMIDAITO, 2013
# Average Reward 		=   -1.531
# Best Score 	 =    0.416 @ Iteration No. 37
# Iteration 40:  TOKYO, 2005
# Average Reward 		=   -1.355
# Best Score 	 =    0.416 @ Iteration No. 37
# Iteration 41:  TOKYO, 2008
# Average Reward 		=   -0.268
# Best Score 	 =    0.416 @ Iteration No. 37
# Iteration 42:  WAKKANAI, 2008
# Average Reward 		=    0.443
# Best Score 	 =    0.416 @ Iteration No. 37
# Saving Model
# Iteration 43:  TOKYO, 2005
# Average Reward 		=    0.651
# Best Score 	 =    0.443 @ Iteration No. 42
# Saving Model
# Iteration 44:  MINAMIDAITO, 2012
# Average Reward 		=   -0.042
# Best Score 	 =    0.651 @ Iteration No. 43
# Iteration 45:  WAKKANAI, 2006
# Average Reward 		=   -0.617
# Best Score 	 =    0.651 @ Iteration No. 43
# Iteration 46:  WAKKANAI, 2014
# Average Reward 		=   -0.405
# Best Score 	 =    0.651 @ Iteration No. 43
# Iteration 47:  TOKYO, 2013
# Average Reward 		=   -0.152
# Best Score 	 =    0.651 @ Iteration No. 43
# Iteration 48:  MINAMIDAITO, 2010
# Average Reward 		=    0.415
# Best Score 	 =    0.651 @ Iteration No. 43
# Iteration 49:  TOKYO, 2010
# Average Reward 		=    0.280
# Best Score 	 =    0.651 @ Iteration No. 43
# Iteration 50:  TOKYO, 2005
# Average Reward 		=   -0.142
# Best Score 	 =    0.651 @ Iteration No. 43
# Iteration 51:  TOKYO, 2012
# Average Reward 		=   -0.070
# Best Score 	 =    0.651 @ Iteration No. 43
# Iteration 52:  TOKYO, 2006
# Average Reward 		=    0.004
# Best Score 	 =    0.651 @ Iteration No. 43
# Iteration 53:  TOKYO, 2005
# Average Reward 		=   -0.032
# Best Score 	 =    0.651 @ Iteration No. 43
# Iteration 54:  TOKYO, 2007
# Average Reward 		=   -0.197
# Best Score 	 =    0.651 @ Iteration No. 43
# Iteration 55:  MINAMIDAITO, 2011
# Average Reward 		=   -0.304
# Best Score 	 =    0.651 @ Iteration No. 43
# Iteration 56:  MINAMIDAITO, 2006
# Average Reward 		=   -0.508
# Best Score 	 =    0.651 @ Iteration No. 43
# Iteration 57:  TOKYO, 2006
# Average Reward 		=   -0.785
# Best Score 	 =    0.651 @ Iteration No. 43
# Iteration 58:  WAKKANAI, 2010
# Average Reward 		=   -0.576
# Best Score 	 =    0.651 @ Iteration No. 43
# Iteration 59:  MINAMIDAITO, 2005
# Average Reward 		=   -0.635
# Best Score 	 =    0.651 @ Iteration No. 43
# Iteration 60:  TOKYO, 2010
# Average Reward 		=   -1.072
# Best Score 	 =    0.651 @ Iteration No. 43
# Iteration 61:  TOKYO, 2013
# Average Reward 		=   -0.712
# Best Score 	 =    0.651 @ Iteration No. 43
# Iteration 62:  TOKYO, 2006
# Average Reward 		=    0.069
# Best Score 	 =    0.651 @ Iteration No. 43
# Iteration 63:  WAKKANAI, 2009
# Average Reward 		=    0.158
# Best Score 	 =    0.651 @ Iteration No. 43
# Iteration 64:  MINAMIDAITO, 2011
# Average Reward 		=   -0.764
# Best Score 	 =    0.651 @ Iteration No. 43
# Iteration 65:  WAKKANAI, 2008
# Average Reward 		=   -1.551
# Best Score 	 =    0.651 @ Iteration No. 43
# Iteration 66:  WAKKANAI, 2007
# Average Reward 		=   -0.871
# Best Score 	 =    0.651 @ Iteration No. 43
# Iteration 67:  TOKYO, 2006
# Average Reward 		=    0.463
# Best Score 	 =    0.651 @ Iteration No. 43
# Iteration 68:  TOKYO, 2010
# Average Reward 		=    0.475
# Best Score 	 =    0.651 @ Iteration No. 43
# Iteration 69:  TOKYO, 2010
# Average Reward 		=   -1.162
# Best Score 	 =    0.651 @ Iteration No. 43
# Iteration 70:  WAKKANAI, 2011
# Average Reward 		=   -1.525
# Best Score 	 =    0.651 @ Iteration No. 43
# Iteration 71:  WAKKANAI, 2006
# Average Reward 		=   -1.261
# Best Score 	 =    0.651 @ Iteration No. 43
# Iteration 72:  WAKKANAI, 2014
# Average Reward 		=    0.426
# Best Score 	 =    0.651 @ Iteration No. 43
# Iteration 73:  MINAMIDAITO, 2014
# Average Reward 		=   -0.308
# Best Score 	 =    0.651 @ Iteration No. 43
# Iteration 74:  WAKKANAI, 2012
# Average Reward 		=   -0.686
# Best Score 	 =    0.651 @ Iteration No. 43
# Iteration 75:  TOKYO, 2010
# Average Reward 		=   -1.175
# Best Score 	 =    0.651 @ Iteration No. 43
# Iteration 76:  MINAMIDAITO, 2010
# Average Reward 		=   -0.056
# Best Score 	 =    0.651 @ Iteration No. 43
# Iteration 77:  TOKYO, 2010
# Average Reward 		=   -1.369
# Best Score 	 =    0.651 @ Iteration No. 43
# Iteration 78:  WAKKANAI, 2006
# Average Reward 		=   -1.235
# Best Score 	 =    0.651 @ Iteration No. 43
# Iteration 79:  WAKKANAI, 2007
# Average Reward 		=   -0.320
# Best Score 	 =    0.651 @ Iteration No. 43
# Iteration 80:  TOKYO, 2007
# Average Reward 		=   -0.824
# Best Score 	 =    0.651 @ Iteration No. 43
# Iteration 81:  MINAMIDAITO, 2013
# Average Reward 		=    0.584
# Best Score 	 =    0.651 @ Iteration No. 43
# Iteration 82:  MINAMIDAITO, 2007
# Average Reward 		=    0.553
# Best Score 	 =    0.651 @ Iteration No. 43
# Iteration 83:  WAKKANAI, 2012
# Average Reward 		=   -1.050
# Best Score 	 =    0.651 @ Iteration No. 43
# Iteration 84:  TOKYO, 2009
# Average Reward 		=   -2.008
# Best Score 	 =    0.651 @ Iteration No. 43
# Iteration 85:  WAKKANAI, 2007
# Average Reward 		=    0.069
# Best Score 	 =    0.651 @ Iteration No. 43
# Iteration 86:  MINAMIDAITO, 2011
# Average Reward 		=    0.228
# Best Score 	 =    0.651 @ Iteration No. 43
# Iteration 87:  TOKYO, 2007
# Average Reward 		=    0.723
# Best Score 	 =    0.651 @ Iteration No. 43
# Saving Model
# Iteration 88:  WAKKANAI, 2006
# Average Reward 		=    0.652
# Best Score 	 =    0.723 @ Iteration No. 87
# Iteration 89:  TOKYO, 2011
# Average Reward 		=   -0.827
# Best Score 	 =    0.723 @ Iteration No. 87
# Iteration 90:  WAKKANAI, 2013
# Average Reward 		=   -1.230
# Best Score 	 =    0.723 @ Iteration No. 87
# Iteration 91:  TOKYO, 2014
# Average Reward 		=    0.077
# Best Score 	 =    0.723 @ Iteration No. 87
# Iteration 92:  MINAMIDAITO, 2014
# Average Reward 		=    0.291
# Best Score 	 =    0.723 @ Iteration No. 87
# Iteration 93:  TOKYO, 2012
# Average Reward 		=   -0.441
# Best Score 	 =    0.723 @ Iteration No. 87
# Iteration 94:  TOKYO, 2012
# Average Reward 		=   -0.111
# Best Score 	 =    0.723 @ Iteration No. 87
# Iteration 95:  MINAMIDAITO, 2006
# Average Reward 		=   -0.157
# Best Score 	 =    0.723 @ Iteration No. 87
# Iteration 96:  TOKYO, 2008
# Average Reward 		=    0.474
# Best Score 	 =    0.723 @ Iteration No. 87
# Iteration 97:  MINAMIDAITO, 2014
# Average Reward 		=   -0.835
# Best Score 	 =    0.723 @ Iteration No. 87
# Iteration 98:  MINAMIDAITO, 2012
# Average Reward 		=    0.208
# Best Score 	 =    0.723 @ Iteration No. 87
# Iteration 99:  TOKYO, 2005
# Average Reward 		=   -1.200
# Best Score 	 =    0.723 @ Iteration No. 87
# (-3, 1)

# %%
#BFILENAME -> loads the best model
#TFILENAME -> loads the last model
MODELFILE = BFILENAME
TEST_LOCATION = 'tokyo'
TEST_YEAR = '2018'
dqn = DQN()
for TEST_LOCATION in ['tokyo','wakkanai','minamidaito']:
    test_model(TEST_LOCATION, TEST_YEAR, MODELFILE, dqn)
# Out:
# Year run test (Greedy Policy)
# Model Used:  bestLZ2AL2VV.pt
# End of Test
# Average Reward for TOKYO,2018 = 1.955520471809451
# Year run test (Greedy Policy)
# Model Used:  bestLZ2AL2VV.pt
# End of Test
# Average Reward for WAKKANAI,2018 = 1.470218412680023
# Year run test (Greedy Policy)
# Model Used:  bestLZ2AL2VV.pt
# End of Test
# Average Reward for MINAMIDAITO,2018 = 1.9421196884254528

# %%
# TEST_YEAR = 2018
# for TEST_LOCATION in ['tokyo','wakkanai','minamidaito']:
#     test_model(TEST_LOCATION, TEST_YEAR)

# %%
# dqn = DQN()
# capm = CAPM(TEST_LOCATION,TEST_YEAR, shuffle=False, trainmode=False) #if reset is True
# capm.eno = ENO(TEST_LOCATION,TEST_YEAR, shuffle=False, day_balance=False) #instantiate the environment inside the CAPM class
# capm.HMAX = capm.eno.SMAX #maximum power output of solar cell is set in CAPM object using the value in ENO object


# # load the required model
# dqn.eval_net.load_state_dict(torch.load(MODELFILE))
# dqn.eval_net.eval()
# print('Model Used: ',MODELFILE)

# s, r, day_end, year_end = capm.reset()
# yr_test_record = np.empty(4)

# while True:
#     a = dqn.choose_greedy_action(s)

#     #state = [batt, enp, henergy, fcast]
#     yr_test_record = np.vstack((yr_test_record, [s[0],s[2],r, a])) #record battery, henergy, reward and action

#     # take action
#     s_, r, day_end, year_end = capm.step(a)
    
# #     if day_end:
# #         if (capm.BMIN ==capm.batt or capm.batt == capm.BMAX):
# #             capm.batt = capm.BOPT
        

#     if year_end:
#         print("End of Test")
#         break

#     s = s_

# yr_test_record = np.delete(yr_test_record, 0, 0) #remove the first row which is garbage

# #Plot the reward and battery for the entire year run
# title = TEST_LOCATION.upper() + ',' + str(TEST_YEAR)

# NO_OF_DAYS = capm.eno.NO_OF_DAYS
# yr_test_reward_rec = yr_test_record[:,2]
# yr_test_reward_rec = yr_test_reward_rec[yr_test_reward_rec != 0]
# print('Average Reward for',title, '=', np.mean(yr_test_reward_rec))


# fig = plt.figure(figsize=(24,10))
# fig.suptitle(title, fontsize=15)

# #     ax1 = fig.add_subplot(211)
# #     ax1.plot(yr_test_reward_rec)
# #     ax1.set_title("\n\nYear Run Reward")
# #     ax1.set_ylim([-3,1])

# ax2 = fig.add_subplot(111)
# ax2.plot(yr_test_record[:,0],'r')
# ax2.set_title("\n\nYear Run Battery")
# ax2.set_ylim([0,1])
# plt.sca(ax2)
# plt.xticks(np.arange(0, NO_OF_DAYS*24, 50*24),np.arange(0,NO_OF_DAYS,50))

# fig.tight_layout()
# plt.show()

# %%
# #Plot the reward and battery for the entire year run on a day by day basis
# title = TEST_LOCATION.upper() + ',' + str(TEST_YEAR)
# TIME_AXIS = np.arange(0,capm.eno.TIME_STEPS)
# for DAY in range(150,170):#capm.eno.NO_OF_DAYS):
#     START = DAY*24
#     END = START+24

#     daytitle = title + ' - DAY ' + str(DAY)
#     fig = plt.figure(figsize=(16,4))
#     st = fig.suptitle(daytitle)

#     ax2 = fig.add_subplot(121)
#     ax2.plot(yr_test_record[START:END,1],'g')
#     ax2.set_title("HARVESTED ENERGY")
#     plt.xlabel("Hour")
#     ax2.set_ylim([0,1])

#     #plot battery for year run
#     ax1 = fig.add_subplot(122)
#     ax1.plot(TIME_AXIS,yr_test_record[START:END,0],'r') 
# #     ax1.plot(TIME_AXIS, np.ones(capm.eno.TIME_STEPS)*capm.BOPT/capm.BMAX,'r--')
#     ax1.plot(TIME_AXIS, np.ones(capm.eno.TIME_STEPS)*yr_test_record[START,0],'r--')
#     ax1.text(0.1, 0.2, "BINIT = %.2f\n" %(yr_test_record[START,0]),fontsize=11, ha='left')
#     ax1.text(0.1, 0.4, "TENP = %.2f\n" %(capm.BOPT/capm.BMAX-yr_test_record[END,0]),fontsize=11, ha='left')
#     ax1.text(0.1, 0.3, "BMEAN = %.2f\n" %(np.mean(yr_test_record[START:END,0])),fontsize=11, ha='left')



#     ax1.set_title("YEAR RUN TEST")
#     if END < (capm.eno.NO_OF_DAYS*capm.eno.TIME_STEPS):
#         ax1.text(0.1, 0, "REWARD = %.2f\n" %(yr_test_record[END,2]),fontsize=13, ha='left')
#     plt.xlabel("Hour")
#     ax1.set_ylabel('Battery', color='r',fontsize=12)
#     ax1.set_ylim([0,1])

#     #plot actions for year run
#     ax1a = ax1.twinx()
#     ax1a.plot(yr_test_record[START:END,3])
#     ax1a.set_ylim([0,N_ACTIONS])
#     ax1a.set_ylabel('Duty Cycle', color='b',fontsize=12)

#     fig.tight_layout()
#     st.set_y(0.95)
#     fig.subplots_adjust(top=0.75)
#     plt.show()
