# %%
# %matplotlib inline

from os.path import dirname, abspath, join
from os import getcwd
import sys

THIS_DIR = getcwd()
CLASS_DIR = abspath(join(THIS_DIR, '../../..', 'dsnclasses'))
sys.path.append(CLASS_DIR)

import random
import string
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from IPython.display import clear_output

from ENOnormal import ENO
from CAPMr3 import CAPM
from NN5 import DQN as DQN
from globalvar import *

# %%
def test_model(TEST_LOCATION, TEST_YEAR, MODELFILE, dqn):

    print('\nYear run test (Greedy Policy)')

#     dqn = DQN()
    capm = CAPM(TEST_LOCATION,TEST_YEAR, shuffle=False, trainmode=False) #if reset is True
    capm.eno = ENO(TEST_LOCATION,TEST_YEAR, shuffle=False, day_balance=False) #instantiate the environment inside the CAPM class
    capm.HMAX = capm.eno.SMAX #maximum power output of solar cell is set in CAPM object using the value in ENO object

    # load the required model
    dqn.eval_net.load_state_dict(torch.load(MODELFILE))
    dqn.eval_net.eval()
    print('Model Used: ',MODELFILE)

    s, r, day_end, year_end = capm.reset()
    yr_test_record = np.empty(4)

    while True:
        a = dqn.choose_greedy_action(s)

        #state = [batt, enp, henergy, fcast]
        yr_test_record = np.vstack((yr_test_record, [s[0],s[2],r, a])) #record battery, henergy, reward and action

        # take action
        s_, r, day_end, year_end = capm.step(a)

        if year_end:
            print("End of Test")
            break

        s = s_

    yr_test_record = np.delete(yr_test_record, 0, 0) #remove the first row which is garbage
    NO_OF_DAYS = capm.eno.NO_OF_DAYS
    yr_test_reward_rec = yr_test_record[:,2]
    yr_test_reward_rec = yr_test_reward_rec[yr_test_reward_rec != 0]
    
    #Plot the reward and battery for the entire year run
    title = TEST_LOCATION.upper() + ',' + str(TEST_YEAR)
    print('Average Reward for',title, '=', np.mean(yr_test_reward_rec))

    fig = plt.figure(figsize=(24,3))
    fig.suptitle(title, fontsize=15)

#     ax1 = fig.add_subplot(211)
#     ax1.plot(yr_test_reward_rec)
#     ax1.set_title("\n\nYear Run Reward")
#     ax1.set_ylim([-3,1])

    ax2 = fig.add_subplot(111)
    ax2.plot(yr_test_record[:,0],'r')
    ax2.set_title("\n\nYear Run Battery")
    ax2.set_ylim([0,1])
    plt.sca(ax2)
    plt.xticks(np.arange(0, NO_OF_DAYS*24, 50*24),np.arange(0,NO_OF_DAYS,50))

    fig.tight_layout()
    plt.show()    
    return 0

# %%
#TRAIN USING data from TOKYO, WAKKANAI and MINAMIDAITO FROM 2005 to 2014
dqn = DQN()

NO_OF_ITERATIONS = 100

best_iteration = -1
best_avg_reward = -1000 #initialize best average reward to very low value
PFILENAME = ''.join(random.choice(string.ascii_uppercase + string.digits) for _ in range(8)) #create random filename
BFILENAME = "best"+PFILENAME + ".pt" #this file stores the best model
TFILENAME = "terminal"+PFILENAME + ".pt" #this file stores the last model

avg_reward_rec = [] #record the yearly average rewards over the entire duration of training
print('\nTRAINING IN PROGRESS\n')

for iteration in range(NO_OF_ITERATIONS):
    LOCATION = random.choice(['tokyo','wakkanai','minamidaito'])
    YEAR = random.choice(np.arange(2005,2015))
    capm = CAPM(LOCATION,YEAR,shuffle=True, trainmode=True) #instantiate the CAPM class
    capm.eno = ENO(LOCATION,YEAR, shuffle=True, day_balance=True) #instantiate the environment inside the CAPM class
    capm.HMAX = capm.eno.SMAX #maximum power output of solar cell is set in CAPM object using the value in ENO object
#     clear_output()
    print('Iteration {}:  {}, {} '.format(iteration, LOCATION.upper(), YEAR))

    s, r, day_end, year_end = capm.reset()
    record = np.empty(4) #record for battery, henergy, reward and action
    transition_rec = np.zeros((capm.eno.TIME_STEPS, N_STATES * 2 + 2)) #record all the transition in one day

    while True:
        a = dqn.choose_action(s)

        # present state = [batt, enp, henergy]
        record = np.vstack((record, [s[0],s[2],r, a])) # record battery, henergy, reward and action for troubleshooting
                                                       # However, we are interested only in the reward

        # take action
        s_, r, day_end, year_end = capm.step(a)

        temp_transitions = np.hstack((s, [a, r], s_))
        transition_rec[capm.eno.hr-1,:] = temp_transitions

        if (day_end):
            transition_rec[:,5] = r #broadcast reward to all states
            decay_factor = [i for i in (LAMBDA**n for n in reversed(range(0, capm.eno.TIME_STEPS)))]
            transition_rec[:,5] = transition_rec[:,5] * decay_factor #decay reward proportionately
            dqn.store_day_transition(transition_rec)

        if dqn.memory_counter > MEMORY_CAPACITY:
            dqn.learn()

        if (year_end):
    #             print("End of Year")
            break

        # transition to new state
        s = s_

    record = np.delete(record, 0, 0) #remove the first row which is garbage
    reward_rec = record[:,2] #extract reward information from the record array
    reward_rec = reward_rec[reward_rec != 0] #remove all zero rewards in the middle of the days
    print("Average Reward \t\t= {:8.3f}".format(np.mean(reward_rec)))

    # Check if reward beats the High Score and possible save it    
    if (iteration > 19): #save the best models only after 20 iterations
        print("Best Score \t = {:8.3f} @ Iteration No. {}".format(best_avg_reward, best_iteration))
        if(best_avg_reward < np.mean(reward_rec)):
            best_iteration = iteration
            best_avg_reward = np.mean(reward_rec)
            print("Saving Model")
            torch.save(dqn.eval_net.state_dict(), BFILENAME)
    else:
        print("\r")
    # Log the average reward in avg_reward_rec
    avg_reward_rec = np.append(avg_reward_rec, np.mean(reward_rec))

    # End of training
# Save the last model
torch.save(dqn.eval_net.state_dict(), TFILENAME) 

# Plot the average reward log
plt.plot(avg_reward_rec,'b')
plt.ylim([-3,1])
# Out:
# TRAINING IN PROGRESS
#
# Iteration 0:  MINAMIDAITO, 2005
# Average Reward 		=   -1.246
#
# Iteration 1:  MINAMIDAITO, 2011
# Average Reward 		=   -0.133
#
# Iteration 2:  MINAMIDAITO, 2011
# Average Reward 		=    0.063
#
# Iteration 3:  WAKKANAI, 2011
# Average Reward 		=   -0.507
#
# Iteration 4:  MINAMIDAITO, 2007
# Average Reward 		=   -0.795
#
# Iteration 5:  MINAMIDAITO, 2009
# Average Reward 		=   -0.159
#
# Iteration 6:  WAKKANAI, 2007
# Average Reward 		=    0.077
#
# Iteration 7:  WAKKANAI, 2005
# Average Reward 		=    0.560
#
# Iteration 8:  TOKYO, 2011
# Average Reward 		=    0.133
#
# Iteration 9:  TOKYO, 2008
# Average Reward 		=   -0.059
#
# Iteration 10:  MINAMIDAITO, 2014
# Average Reward 		=   -0.136
#
# Iteration 11:  TOKYO, 2005
# Average Reward 		=    0.380
#
# Iteration 12:  TOKYO, 2014
# Average Reward 		=    0.099
#
# Iteration 13:  TOKYO, 2010
# Average Reward 		=   -0.240
#
# Iteration 14:  TOKYO, 2012
# Average Reward 		=   -0.572
#
# Iteration 15:  MINAMIDAITO, 2013
# Average Reward 		=   -0.444
#
# Iteration 16:  TOKYO, 2007
# Average Reward 		=   -0.737
#
# Iteration 17:  WAKKANAI, 2012
# Average Reward 		=    0.317
#
# Iteration 18:  TOKYO, 2012
# Average Reward 		=   -0.840
#
# Iteration 19:  MINAMIDAITO, 2012
# Average Reward 		=   -0.211
#
# Iteration 20:  WAKKANAI, 2011
# Average Reward 		=    0.192
# Best Score 	 = -1000.000 @ Iteration No. -1
# Saving Model
# Iteration 21:  WAKKANAI, 2007
# Average Reward 		=    0.221
# Best Score 	 =    0.192 @ Iteration No. 20
# Saving Model
# Iteration 22:  WAKKANAI, 2012
# Average Reward 		=   -0.260
# Best Score 	 =    0.221 @ Iteration No. 21
# Iteration 23:  WAKKANAI, 2010
# Average Reward 		=   -1.304
# Best Score 	 =    0.221 @ Iteration No. 21
# Iteration 24:  TOKYO, 2007
# Average Reward 		=   -0.173
# Best Score 	 =    0.221 @ Iteration No. 21
# Iteration 25:  TOKYO, 2012
# Average Reward 		=   -0.884
# Best Score 	 =    0.221 @ Iteration No. 21
# Iteration 26:  MINAMIDAITO, 2009
# Average Reward 		=   -0.545
# Best Score 	 =    0.221 @ Iteration No. 21
# Iteration 27:  WAKKANAI, 2012
# Average Reward 		=   -1.761
# Best Score 	 =    0.221 @ Iteration No. 21
# Iteration 28:  MINAMIDAITO, 2006
# Average Reward 		=   -0.489
# Best Score 	 =    0.221 @ Iteration No. 21
# Iteration 29:  MINAMIDAITO, 2012
# Average Reward 		=    0.274
# Best Score 	 =    0.221 @ Iteration No. 21
# Saving Model
# Iteration 30:  TOKYO, 2014
# Average Reward 		=   -1.075
# Best Score 	 =    0.274 @ Iteration No. 29
# Iteration 31:  MINAMIDAITO, 2010
# Average Reward 		=   -0.448
# Best Score 	 =    0.274 @ Iteration No. 29
# Iteration 32:  WAKKANAI, 2014
# Average Reward 		=   -1.618
# Best Score 	 =    0.274 @ Iteration No. 29
# Iteration 33:  WAKKANAI, 2007
# Average Reward 		=   -1.031
# Best Score 	 =    0.274 @ Iteration No. 29
# Iteration 34:  WAKKANAI, 2009
# Average Reward 		=    0.367
# Best Score 	 =    0.274 @ Iteration No. 29
# Saving Model
# Iteration 35:  MINAMIDAITO, 2011
# Average Reward 		=    0.174
# Best Score 	 =    0.367 @ Iteration No. 34
# Iteration 36:  WAKKANAI, 2011
# Average Reward 		=   -1.246
# Best Score 	 =    0.367 @ Iteration No. 34
# Iteration 37:  TOKYO, 2010
# Average Reward 		=   -1.422
# Best Score 	 =    0.367 @ Iteration No. 34
# Iteration 38:  WAKKANAI, 2010
# Average Reward 		=   -1.719
# Best Score 	 =    0.367 @ Iteration No. 34
# Iteration 39:  TOKYO, 2012
# Average Reward 		=   -1.668
# Best Score 	 =    0.367 @ Iteration No. 34
# Iteration 40:  MINAMIDAITO, 2012
# Average Reward 		=    0.310
# Best Score 	 =    0.367 @ Iteration No. 34
# Iteration 41:  TOKYO, 2012
# Average Reward 		=    0.510
# Best Score 	 =    0.367 @ Iteration No. 34
# Saving Model
# Iteration 42:  TOKYO, 2013
# Average Reward 		=   -1.385
# Best Score 	 =    0.510 @ Iteration No. 41
# Iteration 43:  WAKKANAI, 2007
# Average Reward 		=    0.007
# Best Score 	 =    0.510 @ Iteration No. 41
# Iteration 44:  MINAMIDAITO, 2013
# Average Reward 		=   -0.335
# Best Score 	 =    0.510 @ Iteration No. 41
# Iteration 45:  MINAMIDAITO, 2007
# Average Reward 		=   -0.020
# Best Score 	 =    0.510 @ Iteration No. 41
# Iteration 46:  WAKKANAI, 2006
# Average Reward 		=   -1.141
# Best Score 	 =    0.510 @ Iteration No. 41
# Iteration 47:  WAKKANAI, 2012
# Average Reward 		=   -0.864
# Best Score 	 =    0.510 @ Iteration No. 41
# Iteration 48:  MINAMIDAITO, 2013
# Average Reward 		=   -0.997
# Best Score 	 =    0.510 @ Iteration No. 41
# Iteration 49:  MINAMIDAITO, 2008
# Average Reward 		=   -1.625
# Best Score 	 =    0.510 @ Iteration No. 41
# Iteration 50:  TOKYO, 2010
# Average Reward 		=   -1.326
# Best Score 	 =    0.510 @ Iteration No. 41
# Iteration 51:  MINAMIDAITO, 2007
# Average Reward 		=    0.156
# Best Score 	 =    0.510 @ Iteration No. 41
# Iteration 52:  WAKKANAI, 2014
# Average Reward 		=   -0.467
# Best Score 	 =    0.510 @ Iteration No. 41
# Iteration 53:  WAKKANAI, 2007
# Average Reward 		=   -1.581
# Best Score 	 =    0.510 @ Iteration No. 41
# Iteration 54:  TOKYO, 2012
# Average Reward 		=   -1.208
# Best Score 	 =    0.510 @ Iteration No. 41
# Iteration 55:  TOKYO, 2012
# Average Reward 		=   -1.598
# Best Score 	 =    0.510 @ Iteration No. 41
# Iteration 56:  TOKYO, 2005
# Average Reward 		=   -1.430
# Best Score 	 =    0.510 @ Iteration No. 41
# Iteration 57:  TOKYO, 2011
# Average Reward 		=    0.123
# Best Score 	 =    0.510 @ Iteration No. 41
# Iteration 58:  TOKYO, 2010
# Average Reward 		=    0.004
# Best Score 	 =    0.510 @ Iteration No. 41
# Iteration 59:  WAKKANAI, 2005
# Average Reward 		=    0.431
# Best Score 	 =    0.510 @ Iteration No. 41
# Iteration 60:  MINAMIDAITO, 2012
# Average Reward 		=    0.603
# Best Score 	 =    0.510 @ Iteration No. 41
# Saving Model
# Iteration 61:  MINAMIDAITO, 2013
# Average Reward 		=   -0.309
# Best Score 	 =    0.603 @ Iteration No. 60
# Iteration 62:  TOKYO, 2007
# Average Reward 		=   -1.534
# Best Score 	 =    0.603 @ Iteration No. 60
# Iteration 63:  TOKYO, 2009
# Average Reward 		=   -1.127
# Best Score 	 =    0.603 @ Iteration No. 60
# Iteration 64:  MINAMIDAITO, 2007
# Average Reward 		=   -0.592
# Best Score 	 =    0.603 @ Iteration No. 60
# Iteration 65:  TOKYO, 2010
# Average Reward 		=   -0.974
# Best Score 	 =    0.603 @ Iteration No. 60
# Iteration 66:  WAKKANAI, 2010
# Average Reward 		=   -0.023
# Best Score 	 =    0.603 @ Iteration No. 60
# Iteration 67:  MINAMIDAITO, 2010
# Average Reward 		=    0.273
# Best Score 	 =    0.603 @ Iteration No. 60
# Iteration 68:  MINAMIDAITO, 2014
# Average Reward 		=   -1.795
# Best Score 	 =    0.603 @ Iteration No. 60
# Iteration 69:  MINAMIDAITO, 2008
# Average Reward 		=   -1.313
# Best Score 	 =    0.603 @ Iteration No. 60
# Iteration 70:  WAKKANAI, 2005
# Average Reward 		=    0.033
# Best Score 	 =    0.603 @ Iteration No. 60
# Iteration 71:  TOKYO, 2014
# Average Reward 		=    0.487
# Best Score 	 =    0.603 @ Iteration No. 60
# Iteration 72:  TOKYO, 2007
# Average Reward 		=    0.586
# Best Score 	 =    0.603 @ Iteration No. 60
# Iteration 73:  WAKKANAI, 2013
# Average Reward 		=    0.387
# Best Score 	 =    0.603 @ Iteration No. 60
# Iteration 74:  WAKKANAI, 2014
# Average Reward 		=    0.279
# Best Score 	 =    0.603 @ Iteration No. 60
# Iteration 75:  WAKKANAI, 2006
# Average Reward 		=   -1.675
# Best Score 	 =    0.603 @ Iteration No. 60
# Iteration 76:  TOKYO, 2012
# Average Reward 		=   -0.186
# Best Score 	 =    0.603 @ Iteration No. 60
# Iteration 77:  MINAMIDAITO, 2006
# Average Reward 		=   -0.088
# Best Score 	 =    0.603 @ Iteration No. 60
# Iteration 78:  TOKYO, 2006
# Average Reward 		=   -0.737
# Best Score 	 =    0.603 @ Iteration No. 60
# Iteration 79:  TOKYO, 2006
# Average Reward 		=   -0.455
# Best Score 	 =    0.603 @ Iteration No. 60
# Iteration 80:  WAKKANAI, 2014
# Average Reward 		=    0.484
# Best Score 	 =    0.603 @ Iteration No. 60
# Iteration 81:  WAKKANAI, 2006
# Average Reward 		=   -0.661
# Best Score 	 =    0.603 @ Iteration No. 60
# Iteration 82:  WAKKANAI, 2011
# Average Reward 		=    0.328
# Best Score 	 =    0.603 @ Iteration No. 60
# Iteration 83:  TOKYO, 2008
# Average Reward 		=   -0.768
# Best Score 	 =    0.603 @ Iteration No. 60
# Iteration 84:  TOKYO, 2014
# Average Reward 		=   -0.298
# Best Score 	 =    0.603 @ Iteration No. 60
# Iteration 85:  TOKYO, 2007
# Average Reward 		=   -0.882
# Best Score 	 =    0.603 @ Iteration No. 60
# Iteration 86:  WAKKANAI, 2012
# Average Reward 		=   -0.668
# Best Score 	 =    0.603 @ Iteration No. 60
# Iteration 87:  TOKYO, 2007
# Average Reward 		=   -1.097
# Best Score 	 =    0.603 @ Iteration No. 60
# Iteration 88:  TOKYO, 2006
# Average Reward 		=   -0.762
# Best Score 	 =    0.603 @ Iteration No. 60
# Iteration 89:  TOKYO, 2012
# Average Reward 		=   -0.969
# Best Score 	 =    0.603 @ Iteration No. 60
# Iteration 90:  MINAMIDAITO, 2014
# Average Reward 		=   -1.376
# Best Score 	 =    0.603 @ Iteration No. 60
# Iteration 91:  WAKKANAI, 2012
# Average Reward 		=   -1.690
# Best Score 	 =    0.603 @ Iteration No. 60
# Iteration 92:  MINAMIDAITO, 2007
# Average Reward 		=   -0.747
# Best Score 	 =    0.603 @ Iteration No. 60
# Iteration 93:  WAKKANAI, 2013
# Average Reward 		=   -1.572
# Best Score 	 =    0.603 @ Iteration No. 60
# Iteration 94:  TOKYO, 2010
# Average Reward 		=   -0.381
# Best Score 	 =    0.603 @ Iteration No. 60
# Iteration 95:  WAKKANAI, 2012
# Average Reward 		=    0.605
# Best Score 	 =    0.603 @ Iteration No. 60
# Saving Model
# Iteration 96:  MINAMIDAITO, 2013
# Average Reward 		=    0.421
# Best Score 	 =    0.605 @ Iteration No. 95
# Iteration 97:  WAKKANAI, 2013
# Average Reward 		=   -0.433
# Best Score 	 =    0.605 @ Iteration No. 95
# Iteration 98:  MINAMIDAITO, 2008
# Average Reward 		=   -1.222
# Best Score 	 =    0.605 @ Iteration No. 95
# Iteration 99:  WAKKANAI, 2012
# Average Reward 		=   -0.388
# Best Score 	 =    0.605 @ Iteration No. 95
# (-3, 1)

# %%
#BFILENAME -> loads the best model
#TFILENAME -> loads the last model
MODELFILE = BFILENAME
TEST_LOCATION = 'tokyo'
TEST_YEAR = '2018'
dqn = DQN()
for TEST_LOCATION in ['tokyo','wakkanai','minamidaito']:
    test_model(TEST_LOCATION, TEST_YEAR, MODELFILE, dqn)
# Out:
# Year run test (Greedy Policy)
# Model Used:  bestQL4NG6KY.pt
# End of Test
# Average Reward for TOKYO,2018 = 0.4915529917724647
# Year run test (Greedy Policy)
# Model Used:  bestQL4NG6KY.pt
# End of Test
# Average Reward for WAKKANAI,2018 = 0.42424696000246653
# Year run test (Greedy Policy)
# Model Used:  bestQL4NG6KY.pt
# End of Test
# Average Reward for MINAMIDAITO,2018 = -0.335967581667276

# %%
# TEST_YEAR = 2018
# for TEST_LOCATION in ['tokyo','wakkanai','minamidaito']:
#     test_model(TEST_LOCATION, TEST_YEAR)

# %%
# dqn = DQN()
# capm = CAPM(TEST_LOCATION,TEST_YEAR, shuffle=False, trainmode=False) #if reset is True
# capm.eno = ENO(TEST_LOCATION,TEST_YEAR, shuffle=False, day_balance=False) #instantiate the environment inside the CAPM class
# capm.HMAX = capm.eno.SMAX #maximum power output of solar cell is set in CAPM object using the value in ENO object


# # load the required model
# dqn.eval_net.load_state_dict(torch.load(MODELFILE))
# dqn.eval_net.eval()
# print('Model Used: ',MODELFILE)

# s, r, day_end, year_end = capm.reset()
# yr_test_record = np.empty(4)

# while True:
#     a = dqn.choose_greedy_action(s)

#     #state = [batt, enp, henergy, fcast]
#     yr_test_record = np.vstack((yr_test_record, [s[0],s[2],r, a])) #record battery, henergy, reward and action

#     # take action
#     s_, r, day_end, year_end = capm.step(a)
    
# #     if day_end:
# #         if (capm.BMIN ==capm.batt or capm.batt == capm.BMAX):
# #             capm.batt = capm.BOPT
        

#     if year_end:
#         print("End of Test")
#         break

#     s = s_

# yr_test_record = np.delete(yr_test_record, 0, 0) #remove the first row which is garbage

# #Plot the reward and battery for the entire year run
# title = TEST_LOCATION.upper() + ',' + str(TEST_YEAR)

# NO_OF_DAYS = capm.eno.NO_OF_DAYS
# yr_test_reward_rec = yr_test_record[:,2]
# yr_test_reward_rec = yr_test_reward_rec[yr_test_reward_rec != 0]
# print('Average Reward for',title, '=', np.mean(yr_test_reward_rec))


# fig = plt.figure(figsize=(24,10))
# fig.suptitle(title, fontsize=15)

# #     ax1 = fig.add_subplot(211)
# #     ax1.plot(yr_test_reward_rec)
# #     ax1.set_title("\n\nYear Run Reward")
# #     ax1.set_ylim([-3,1])

# ax2 = fig.add_subplot(111)
# ax2.plot(yr_test_record[:,0],'r')
# ax2.set_title("\n\nYear Run Battery")
# ax2.set_ylim([0,1])
# plt.sca(ax2)
# plt.xticks(np.arange(0, NO_OF_DAYS*24, 50*24),np.arange(0,NO_OF_DAYS,50))

# fig.tight_layout()
# plt.show()

# %%
# #Plot the reward and battery for the entire year run on a day by day basis
# title = TEST_LOCATION.upper() + ',' + str(TEST_YEAR)
# TIME_AXIS = np.arange(0,capm.eno.TIME_STEPS)
# for DAY in range(150,170):#capm.eno.NO_OF_DAYS):
#     START = DAY*24
#     END = START+24

#     daytitle = title + ' - DAY ' + str(DAY)
#     fig = plt.figure(figsize=(16,4))
#     st = fig.suptitle(daytitle)

#     ax2 = fig.add_subplot(121)
#     ax2.plot(yr_test_record[START:END,1],'g')
#     ax2.set_title("HARVESTED ENERGY")
#     plt.xlabel("Hour")
#     ax2.set_ylim([0,1])

#     #plot battery for year run
#     ax1 = fig.add_subplot(122)
#     ax1.plot(TIME_AXIS,yr_test_record[START:END,0],'r') 
# #     ax1.plot(TIME_AXIS, np.ones(capm.eno.TIME_STEPS)*capm.BOPT/capm.BMAX,'r--')
#     ax1.plot(TIME_AXIS, np.ones(capm.eno.TIME_STEPS)*yr_test_record[START,0],'r--')
#     ax1.text(0.1, 0.2, "BINIT = %.2f\n" %(yr_test_record[START,0]),fontsize=11, ha='left')
#     ax1.text(0.1, 0.4, "TENP = %.2f\n" %(capm.BOPT/capm.BMAX-yr_test_record[END,0]),fontsize=11, ha='left')
#     ax1.text(0.1, 0.3, "BMEAN = %.2f\n" %(np.mean(yr_test_record[START:END,0])),fontsize=11, ha='left')



#     ax1.set_title("YEAR RUN TEST")
#     if END < (capm.eno.NO_OF_DAYS*capm.eno.TIME_STEPS):
#         ax1.text(0.1, 0, "REWARD = %.2f\n" %(yr_test_record[END,2]),fontsize=13, ha='left')
#     plt.xlabel("Hour")
#     ax1.set_ylabel('Battery', color='r',fontsize=12)
#     ax1.set_ylim([0,1])

#     #plot actions for year run
#     ax1a = ax1.twinx()
#     ax1a.plot(yr_test_record[START:END,3])
#     ax1a.set_ylim([0,N_ACTIONS])
#     ax1a.set_ylabel('Duty Cycle', color='b',fontsize=12)

#     fig.tight_layout()
#     st.set_y(0.95)
#     fig.subplots_adjust(top=0.75)
#     plt.show()
