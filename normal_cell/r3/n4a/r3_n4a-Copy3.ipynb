# %%
# %matplotlib inline

from os.path import dirname, abspath, join
from os import getcwd
import sys

THIS_DIR = getcwd()
CLASS_DIR = abspath(join(THIS_DIR, '../../..', 'dsnclasses'))
sys.path.append(CLASS_DIR)

import random
import string
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from IPython.display import clear_output

from ENOnormal import ENO
from CAPMr3 import CAPM
from NN4a import DQN as DQN
from globalvar import *

# %%
def test_model(TEST_LOCATION, TEST_YEAR, MODELFILE, dqn):

    print('\nYear run test (Greedy Policy)')

#     dqn = DQN()
    capm = CAPM(TEST_LOCATION,TEST_YEAR, shuffle=False, trainmode=False) #if reset is True
    capm.eno = ENO(TEST_LOCATION,TEST_YEAR, shuffle=False, day_balance=False) #instantiate the environment inside the CAPM class
    capm.HMAX = capm.eno.SMAX #maximum power output of solar cell is set in CAPM object using the value in ENO object

    # load the required model
    dqn.eval_net.load_state_dict(torch.load(MODELFILE))
    dqn.eval_net.eval()
    print('Model Used: ',MODELFILE)

    s, r, day_end, year_end = capm.reset()
    yr_test_record = np.empty(4)

    while True:
        a = dqn.choose_greedy_action(s)

        #state = [batt, enp, henergy, fcast]
        yr_test_record = np.vstack((yr_test_record, [s[0],s[2],r, a])) #record battery, henergy, reward and action

        # take action
        s_, r, day_end, year_end = capm.step(a)

        if year_end:
            print("End of Test")
            break

        s = s_

    yr_test_record = np.delete(yr_test_record, 0, 0) #remove the first row which is garbage
    NO_OF_DAYS = capm.eno.NO_OF_DAYS
    yr_test_reward_rec = yr_test_record[:,2]
    yr_test_reward_rec = yr_test_reward_rec[yr_test_reward_rec != 0]
    
    #Plot the reward and battery for the entire year run
    title = TEST_LOCATION.upper() + ',' + str(TEST_YEAR)
    print('Average Reward for',title, '=', np.mean(yr_test_reward_rec))

    fig = plt.figure(figsize=(24,3))
    fig.suptitle(title, fontsize=15)

#     ax1 = fig.add_subplot(211)
#     ax1.plot(yr_test_reward_rec)
#     ax1.set_title("\n\nYear Run Reward")
#     ax1.set_ylim([-3,1])

    ax2 = fig.add_subplot(111)
    ax2.plot(yr_test_record[:,0],'r')
    ax2.set_title("\n\nYear Run Battery")
    ax2.set_ylim([0,1])
    plt.sca(ax2)
    plt.xticks(np.arange(0, NO_OF_DAYS*24, 50*24),np.arange(0,NO_OF_DAYS,50))

    fig.tight_layout()
    plt.show()    
    return 0

# %%
#TRAIN USING data from TOKYO, WAKKANAI and MINAMIDAITO FROM 2005 to 2014
dqn = DQN()

NO_OF_ITERATIONS = 100

best_iteration = -1
best_avg_reward = -1000 #initialize best average reward to very low value
PFILENAME = ''.join(random.choice(string.ascii_uppercase + string.digits) for _ in range(8)) #create random filename
BFILENAME = "best"+PFILENAME + ".pt" #this file stores the best model
TFILENAME = "terminal"+PFILENAME + ".pt" #this file stores the last model

avg_reward_rec = [] #record the yearly average rewards over the entire duration of training
print('\nTRAINING IN PROGRESS\n')

for iteration in range(NO_OF_ITERATIONS):
    LOCATION = random.choice(['tokyo','wakkanai','minamidaito'])
    YEAR = random.choice(np.arange(2005,2015))
    capm = CAPM(LOCATION,YEAR,shuffle=True, trainmode=True) #instantiate the CAPM class
    capm.eno = ENO(LOCATION,YEAR, shuffle=True, day_balance=True) #instantiate the environment inside the CAPM class
    capm.HMAX = capm.eno.SMAX #maximum power output of solar cell is set in CAPM object using the value in ENO object
#     clear_output()
    print('Iteration {}:  {}, {} '.format(iteration, LOCATION.upper(), YEAR))

    s, r, day_end, year_end = capm.reset()
    record = np.empty(4) #record for battery, henergy, reward and action
    transition_rec = np.zeros((capm.eno.TIME_STEPS, N_STATES * 2 + 2)) #record all the transition in one day

    while True:
        a = dqn.choose_action(s)

        # present state = [batt, enp, henergy]
        record = np.vstack((record, [s[0],s[2],r, a])) # record battery, henergy, reward and action for troubleshooting
                                                       # However, we are interested only in the reward

        # take action
        s_, r, day_end, year_end = capm.step(a)

        temp_transitions = np.hstack((s, [a, r], s_))
        transition_rec[capm.eno.hr-1,:] = temp_transitions

        if (day_end):
            transition_rec[:,5] = r #broadcast reward to all states
            decay_factor = [i for i in (LAMBDA**n for n in reversed(range(0, capm.eno.TIME_STEPS)))]
            transition_rec[:,5] = transition_rec[:,5] * decay_factor #decay reward proportionately
            dqn.store_day_transition(transition_rec)

        if dqn.memory_counter > MEMORY_CAPACITY:
            dqn.learn()

        if (year_end):
    #             print("End of Year")
            break

        # transition to new state
        s = s_

    record = np.delete(record, 0, 0) #remove the first row which is garbage
    reward_rec = record[:,2] #extract reward information from the record array
    reward_rec = reward_rec[reward_rec != 0] #remove all zero rewards in the middle of the days
    print("Average Reward \t\t= {:8.3f}".format(np.mean(reward_rec)))

    # Check if reward beats the High Score and possible save it    
    if (iteration > 19): #save the best models only after 20 iterations
        print("Best Score \t = {:8.3f} @ Iteration No. {}".format(best_avg_reward, best_iteration))
        if(best_avg_reward < np.mean(reward_rec)):
            best_iteration = iteration
            best_avg_reward = np.mean(reward_rec)
            print("Saving Model")
            torch.save(dqn.eval_net.state_dict(), BFILENAME)
    else:
        print("\r")
    # Log the average reward in avg_reward_rec
    avg_reward_rec = np.append(avg_reward_rec, np.mean(reward_rec))

    # End of training
# Save the last model
torch.save(dqn.eval_net.state_dict(), TFILENAME) 

# Plot the average reward log
plt.plot(avg_reward_rec,'b')
plt.ylim([-3,1])
# Out:
# TRAINING IN PROGRESS
#
# Iteration 0:  WAKKANAI, 2013
# Average Reward 		=   -1.125
#
# Iteration 1:  WAKKANAI, 2005
# Average Reward 		=   -0.022
#
# Iteration 2:  MINAMIDAITO, 2010
# Average Reward 		=   -0.489
#
# Iteration 3:  WAKKANAI, 2010
# Average Reward 		=    0.203
#
# Iteration 4:  MINAMIDAITO, 2005
# Average Reward 		=   -0.075
#
# Iteration 5:  WAKKANAI, 2009
# Average Reward 		=    0.092
#
# Iteration 6:  TOKYO, 2007
# Average Reward 		=    0.133
#
# Iteration 7:  MINAMIDAITO, 2009
# Average Reward 		=   -0.207
#
# Iteration 8:  WAKKANAI, 2005
# Average Reward 		=   -0.147
#
# Iteration 9:  WAKKANAI, 2005
# Average Reward 		=   -0.217
#
# Iteration 10:  WAKKANAI, 2011
# Average Reward 		=   -0.093
#
# Iteration 11:  TOKYO, 2014
# Average Reward 		=   -0.333
#
# Iteration 12:  WAKKANAI, 2011
# Average Reward 		=   -0.377
#
# Iteration 13:  MINAMIDAITO, 2013
# Average Reward 		=   -0.349
#
# Iteration 14:  WAKKANAI, 2005
# Average Reward 		=   -0.384
#
# Iteration 15:  TOKYO, 2007
# Average Reward 		=   -0.473
#
# Iteration 16:  WAKKANAI, 2006
# Average Reward 		=   -0.194
#
# Iteration 17:  WAKKANAI, 2014
# Average Reward 		=   -0.409
#
# Iteration 18:  MINAMIDAITO, 2008
# Average Reward 		=   -0.328
#
# Iteration 19:  TOKYO, 2005
# Average Reward 		=   -0.371
#
# Iteration 20:  WAKKANAI, 2008
# Average Reward 		=   -0.426
# Best Score 	 = -1000.000 @ Iteration No. -1
# Saving Model
# Iteration 21:  MINAMIDAITO, 2014
# Average Reward 		=   -0.414
# Best Score 	 =   -0.426 @ Iteration No. 20
# Saving Model
# Iteration 22:  WAKKANAI, 2013
# Average Reward 		=   -0.375
# Best Score 	 =   -0.414 @ Iteration No. 21
# Saving Model
# Iteration 23:  TOKYO, 2013
# Average Reward 		=   -0.394
# Best Score 	 =   -0.375 @ Iteration No. 22
# Iteration 24:  TOKYO, 2005
# Average Reward 		=   -0.590
# Best Score 	 =   -0.375 @ Iteration No. 22
# Iteration 25:  TOKYO, 2014
# Average Reward 		=   -0.434
# Best Score 	 =   -0.375 @ Iteration No. 22
# Iteration 26:  WAKKANAI, 2009
# Average Reward 		=   -0.577
# Best Score 	 =   -0.375 @ Iteration No. 22
# Iteration 27:  MINAMIDAITO, 2012
# Average Reward 		=   -0.357
# Best Score 	 =   -0.375 @ Iteration No. 22
# Saving Model
# Iteration 28:  TOKYO, 2014
# Average Reward 		=   -0.309
# Best Score 	 =   -0.357 @ Iteration No. 27
# Saving Model
# Iteration 29:  MINAMIDAITO, 2010
# Average Reward 		=   -0.404
# Best Score 	 =   -0.309 @ Iteration No. 28
# Iteration 30:  WAKKANAI, 2007
# Average Reward 		=   -0.454
# Best Score 	 =   -0.309 @ Iteration No. 28
# Iteration 31:  MINAMIDAITO, 2005
# Average Reward 		=   -0.333
# Best Score 	 =   -0.309 @ Iteration No. 28
# Iteration 32:  WAKKANAI, 2007
# Average Reward 		=   -0.696
# Best Score 	 =   -0.309 @ Iteration No. 28
# Iteration 33:  WAKKANAI, 2012
# Average Reward 		=   -0.403
# Best Score 	 =   -0.309 @ Iteration No. 28
# Iteration 34:  MINAMIDAITO, 2009
# Average Reward 		=   -0.456
# Best Score 	 =   -0.309 @ Iteration No. 28
# Iteration 35:  TOKYO, 2006
# Average Reward 		=   -0.479
# Best Score 	 =   -0.309 @ Iteration No. 28
# Iteration 36:  MINAMIDAITO, 2010
# Average Reward 		=   -0.435
# Best Score 	 =   -0.309 @ Iteration No. 28
# Iteration 37:  MINAMIDAITO, 2010
# Average Reward 		=   -0.626
# Best Score 	 =   -0.309 @ Iteration No. 28
# Iteration 38:  WAKKANAI, 2008
# Average Reward 		=   -0.509
# Best Score 	 =   -0.309 @ Iteration No. 28
# Iteration 39:  WAKKANAI, 2008
# Average Reward 		=   -0.421
# Best Score 	 =   -0.309 @ Iteration No. 28
# Iteration 40:  MINAMIDAITO, 2007
# Average Reward 		=   -0.490
# Best Score 	 =   -0.309 @ Iteration No. 28
# Iteration 41:  WAKKANAI, 2005
# Average Reward 		=   -0.368
# Best Score 	 =   -0.309 @ Iteration No. 28
# Iteration 42:  TOKYO, 2009
# Average Reward 		=   -0.062
# Best Score 	 =   -0.309 @ Iteration No. 28
# Saving Model
# Iteration 43:  MINAMIDAITO, 2012
# Average Reward 		=   -0.269
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 44:  WAKKANAI, 2007
# Average Reward 		=   -0.565
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 45:  MINAMIDAITO, 2012
# Average Reward 		=   -0.586
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 46:  WAKKANAI, 2007
# Average Reward 		=   -0.337
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 47:  MINAMIDAITO, 2007
# Average Reward 		=   -0.350
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 48:  WAKKANAI, 2009
# Average Reward 		=   -0.545
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 49:  MINAMIDAITO, 2006
# Average Reward 		=   -0.559
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 50:  WAKKANAI, 2012
# Average Reward 		=   -0.374
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 51:  WAKKANAI, 2005
# Average Reward 		=   -0.326
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 52:  MINAMIDAITO, 2005
# Average Reward 		=   -0.540
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 53:  MINAMIDAITO, 2010
# Average Reward 		=   -0.673
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 54:  MINAMIDAITO, 2007
# Average Reward 		=   -0.378
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 55:  WAKKANAI, 2007
# Average Reward 		=   -0.362
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 56:  MINAMIDAITO, 2010
# Average Reward 		=   -0.422
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 57:  MINAMIDAITO, 2014
# Average Reward 		=   -0.347
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 58:  TOKYO, 2012
# Average Reward 		=   -0.622
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 59:  WAKKANAI, 2014
# Average Reward 		=   -0.369
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 60:  WAKKANAI, 2014
# Average Reward 		=   -0.274
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 61:  WAKKANAI, 2009
# Average Reward 		=   -0.194
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 62:  TOKYO, 2012
# Average Reward 		=   -0.445
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 63:  WAKKANAI, 2010
# Average Reward 		=   -0.584
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 64:  MINAMIDAITO, 2007
# Average Reward 		=   -0.463
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 65:  WAKKANAI, 2009
# Average Reward 		=   -0.361
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 66:  TOKYO, 2008
# Average Reward 		=   -0.454
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 67:  MINAMIDAITO, 2007
# Average Reward 		=   -0.606
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 68:  WAKKANAI, 2007
# Average Reward 		=   -0.565
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 69:  TOKYO, 2012
# Average Reward 		=   -0.530
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 70:  TOKYO, 2005
# Average Reward 		=   -0.146
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 71:  TOKYO, 2013
# Average Reward 		=   -0.409
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 72:  MINAMIDAITO, 2013
# Average Reward 		=   -0.235
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 73:  TOKYO, 2006
# Average Reward 		=   -0.363
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 74:  MINAMIDAITO, 2011
# Average Reward 		=   -0.572
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 75:  MINAMIDAITO, 2006
# Average Reward 		=   -0.444
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 76:  WAKKANAI, 2007
# Average Reward 		=   -0.539
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 77:  TOKYO, 2006
# Average Reward 		=   -0.359
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 78:  WAKKANAI, 2007
# Average Reward 		=   -0.400
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 79:  WAKKANAI, 2006
# Average Reward 		=   -0.090
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 80:  TOKYO, 2009
# Average Reward 		=   -0.109
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 81:  TOKYO, 2010
# Average Reward 		=   -0.164
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 82:  WAKKANAI, 2005
# Average Reward 		=   -0.253
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 83:  TOKYO, 2007
# Average Reward 		=   -0.548
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 84:  MINAMIDAITO, 2005
# Average Reward 		=   -0.364
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 85:  MINAMIDAITO, 2009
# Average Reward 		=   -0.445
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 86:  WAKKANAI, 2007
# Average Reward 		=   -0.119
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 87:  WAKKANAI, 2013
# Average Reward 		=   -0.200
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 88:  MINAMIDAITO, 2014
# Average Reward 		=   -0.332
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 89:  TOKYO, 2008
# Average Reward 		=   -0.366
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 90:  WAKKANAI, 2012
# Average Reward 		=   -0.417
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 91:  MINAMIDAITO, 2013
# Average Reward 		=   -0.358
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 92:  TOKYO, 2010
# Average Reward 		=   -0.459
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 93:  MINAMIDAITO, 2008
# Average Reward 		=   -0.545
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 94:  TOKYO, 2006
# Average Reward 		=   -0.600
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 95:  TOKYO, 2014
# Average Reward 		=   -0.410
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 96:  WAKKANAI, 2005
# Average Reward 		=   -0.370
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 97:  TOKYO, 2008
# Average Reward 		=   -0.399
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 98:  MINAMIDAITO, 2005
# Average Reward 		=   -0.316
# Best Score 	 =   -0.062 @ Iteration No. 42
# Iteration 99:  MINAMIDAITO, 2014
# Average Reward 		=   -0.370
# Best Score 	 =   -0.062 @ Iteration No. 42
# (-3, 1)

# %%
#BFILENAME -> loads the best model
#TFILENAME -> loads the last model
MODELFILE = BFILENAME
TEST_YEAR = '2018'
dqn = DQN()
for TEST_LOCATION in ['tokyo','wakkanai','minamidaito']:
    test_model(TEST_LOCATION, TEST_YEAR, MODELFILE, dqn)
# Out:
# Year run test (Greedy Policy)
# Model Used:  bestWBFA6KUX.pt
# End of Test
# Average Reward for TOKYO,2018 = -1.3015830056681634
# Year run test (Greedy Policy)
# Model Used:  bestWBFA6KUX.pt
# End of Test
# Average Reward for WAKKANAI,2018 = -1.1495245095762932
# Year run test (Greedy Policy)
# Model Used:  bestWBFA6KUX.pt
# End of Test
# Average Reward for MINAMIDAITO,2018 = -0.7284799159095171

# %%
MODELFILE = TFILENAME
TEST_YEAR = '2018'
dqn = DQN()
for TEST_LOCATION in ['tokyo','wakkanai','minamidaito']:
    test_model(TEST_LOCATION, TEST_YEAR, MODELFILE, dqn)
# Out:
# Year run test (Greedy Policy)
# Model Used:  terminalWBFA6KUX.pt
# End of Test
# Average Reward for TOKYO,2018 = -0.6181292215387866
# Year run test (Greedy Policy)
# Model Used:  terminalWBFA6KUX.pt
# End of Test
# Average Reward for WAKKANAI,2018 = -1.035385758662204
# Year run test (Greedy Policy)
# Model Used:  terminalWBFA6KUX.pt
# End of Test
# Average Reward for MINAMIDAITO,2018 = -1.5053612006034782

# %%
# TEST_YEAR = 2018
# for TEST_LOCATION in ['tokyo','wakkanai','minamidaito']:
#     test_model(TEST_LOCATION, TEST_YEAR)

# %%
# dqn = DQN()
# capm = CAPM(TEST_LOCATION,TEST_YEAR, shuffle=False, trainmode=False) #if reset is True
# capm.eno = ENO(TEST_LOCATION,TEST_YEAR, shuffle=False, day_balance=False) #instantiate the environment inside the CAPM class
# capm.HMAX = capm.eno.SMAX #maximum power output of solar cell is set in CAPM object using the value in ENO object


# # load the required model
# dqn.eval_net.load_state_dict(torch.load(MODELFILE))
# dqn.eval_net.eval()
# print('Model Used: ',MODELFILE)

# s, r, day_end, year_end = capm.reset()
# yr_test_record = np.empty(4)

# while True:
#     a = dqn.choose_greedy_action(s)

#     #state = [batt, enp, henergy, fcast]
#     yr_test_record = np.vstack((yr_test_record, [s[0],s[2],r, a])) #record battery, henergy, reward and action

#     # take action
#     s_, r, day_end, year_end = capm.step(a)
    
# #     if day_end:
# #         if (capm.BMIN ==capm.batt or capm.batt == capm.BMAX):
# #             capm.batt = capm.BOPT
        

#     if year_end:
#         print("End of Test")
#         break

#     s = s_

# yr_test_record = np.delete(yr_test_record, 0, 0) #remove the first row which is garbage

# #Plot the reward and battery for the entire year run
# title = TEST_LOCATION.upper() + ',' + str(TEST_YEAR)

# NO_OF_DAYS = capm.eno.NO_OF_DAYS
# yr_test_reward_rec = yr_test_record[:,2]
# yr_test_reward_rec = yr_test_reward_rec[yr_test_reward_rec != 0]
# print('Average Reward for',title, '=', np.mean(yr_test_reward_rec))


# fig = plt.figure(figsize=(24,10))
# fig.suptitle(title, fontsize=15)

# #     ax1 = fig.add_subplot(211)
# #     ax1.plot(yr_test_reward_rec)
# #     ax1.set_title("\n\nYear Run Reward")
# #     ax1.set_ylim([-3,1])

# ax2 = fig.add_subplot(111)
# ax2.plot(yr_test_record[:,0],'r')
# ax2.set_title("\n\nYear Run Battery")
# ax2.set_ylim([0,1])
# plt.sca(ax2)
# plt.xticks(np.arange(0, NO_OF_DAYS*24, 50*24),np.arange(0,NO_OF_DAYS,50))

# fig.tight_layout()
# plt.show()

# %%
# #Plot the reward and battery for the entire year run on a day by day basis
# title = TEST_LOCATION.upper() + ',' + str(TEST_YEAR)
# TIME_AXIS = np.arange(0,capm.eno.TIME_STEPS)
# for DAY in range(150,170):#capm.eno.NO_OF_DAYS):
#     START = DAY*24
#     END = START+24

#     daytitle = title + ' - DAY ' + str(DAY)
#     fig = plt.figure(figsize=(16,4))
#     st = fig.suptitle(daytitle)

#     ax2 = fig.add_subplot(121)
#     ax2.plot(yr_test_record[START:END,1],'g')
#     ax2.set_title("HARVESTED ENERGY")
#     plt.xlabel("Hour")
#     ax2.set_ylim([0,1])

#     #plot battery for year run
#     ax1 = fig.add_subplot(122)
#     ax1.plot(TIME_AXIS,yr_test_record[START:END,0],'r') 
# #     ax1.plot(TIME_AXIS, np.ones(capm.eno.TIME_STEPS)*capm.BOPT/capm.BMAX,'r--')
#     ax1.plot(TIME_AXIS, np.ones(capm.eno.TIME_STEPS)*yr_test_record[START,0],'r--')
#     ax1.text(0.1, 0.2, "BINIT = %.2f\n" %(yr_test_record[START,0]),fontsize=11, ha='left')
#     ax1.text(0.1, 0.4, "TENP = %.2f\n" %(capm.BOPT/capm.BMAX-yr_test_record[END,0]),fontsize=11, ha='left')
#     ax1.text(0.1, 0.3, "BMEAN = %.2f\n" %(np.mean(yr_test_record[START:END,0])),fontsize=11, ha='left')



#     ax1.set_title("YEAR RUN TEST")
#     if END < (capm.eno.NO_OF_DAYS*capm.eno.TIME_STEPS):
#         ax1.text(0.1, 0, "REWARD = %.2f\n" %(yr_test_record[END,2]),fontsize=13, ha='left')
#     plt.xlabel("Hour")
#     ax1.set_ylabel('Battery', color='r',fontsize=12)
#     ax1.set_ylim([0,1])

#     #plot actions for year run
#     ax1a = ax1.twinx()
#     ax1a.plot(yr_test_record[START:END,3])
#     ax1a.set_ylim([0,N_ACTIONS])
#     ax1a.set_ylabel('Duty Cycle', color='b',fontsize=12)

#     fig.tight_layout()
#     st.set_y(0.95)
#     fig.subplots_adjust(top=0.75)
#     plt.show()
