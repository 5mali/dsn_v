# %%
# %matplotlib inline

from os.path import dirname, abspath, join
from os import getcwd
import sys

THIS_DIR = getcwd()
CLASS_DIR = abspath(join(THIS_DIR, '../../..', 'dsnclasses'))
sys.path.append(CLASS_DIR)

import random
import string
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from IPython.display import clear_output

from ENOsmall import ENO
from CAPMr3 import CAPM
from NN6a import DQN as DQN
from globalvar import *

# %%
def test_model(TEST_LOCATION, TEST_YEAR, MODELFILE, dqn):

    print('\nYear run test (Greedy Policy)')

#     dqn = DQN()
    capm = CAPM(TEST_LOCATION,TEST_YEAR, shuffle=False, trainmode=False) #if reset is True
    capm.eno = ENO(TEST_LOCATION,TEST_YEAR, shuffle=False, day_balance=False) #instantiate the environment inside the CAPM class
    capm.HMAX = capm.eno.SMAX #maximum power output of solar cell is set in CAPM object using the value in ENO object

    # load the required model
    dqn.eval_net.load_state_dict(torch.load(MODELFILE))
    dqn.eval_net.eval()
    print('Model Used: ',MODELFILE)

    s, r, day_end, year_end = capm.reset()
    yr_test_record = np.empty(4)

    while True:
        a = dqn.choose_greedy_action(s)

        #state = [batt, enp, henergy, fcast]
        yr_test_record = np.vstack((yr_test_record, [s[0],s[2],r, a])) #record battery, henergy, reward and action

        # take action
        s_, r, day_end, year_end = capm.step(a)

        if year_end:
            print("End of Test")
            break

        s = s_

    yr_test_record = np.delete(yr_test_record, 0, 0) #remove the first row which is garbage
    NO_OF_DAYS = capm.eno.NO_OF_DAYS
    yr_test_reward_rec = yr_test_record[:,2]
    yr_test_reward_rec = yr_test_reward_rec[yr_test_reward_rec != 0]
    
    #Plot the reward and battery for the entire year run
    title = TEST_LOCATION.upper() + ',' + str(TEST_YEAR)
    print('Average Reward for',title, '=', np.mean(yr_test_reward_rec))

    fig = plt.figure(figsize=(24,3))
    fig.suptitle(title, fontsize=15)

#     ax1 = fig.add_subplot(211)
#     ax1.plot(yr_test_reward_rec)
#     ax1.set_title("\n\nYear Run Reward")
#     ax1.set_ylim([-3,1])

    ax2 = fig.add_subplot(111)
    ax2.plot(yr_test_record[:,0],'r')
    ax2.set_title("\n\nYear Run Battery")
    ax2.set_ylim([0,1])
    plt.sca(ax2)
    plt.xticks(np.arange(0, NO_OF_DAYS*24, 50*24),np.arange(0,NO_OF_DAYS,50))

    fig.tight_layout()
    plt.show()    
    return 0

# %%
#TRAIN USING data from TOKYO, WAKKANAI and MINAMIDAITO FROM 2005 to 2014
dqn = DQN()

NO_OF_ITERATIONS = 100

best_iteration = -1
best_avg_reward = -1000 #initialize best average reward to very low value
PFILENAME = ''.join(random.choice(string.ascii_uppercase + string.digits) for _ in range(8)) #create random filename
BFILENAME = "best"+PFILENAME + ".pt" #this file stores the best model
TFILENAME = "terminal"+PFILENAME + ".pt" #this file stores the last model

avg_reward_rec = [] #record the yearly average rewards over the entire duration of training
print('\nTRAINING IN PROGRESS\n')

for iteration in range(NO_OF_ITERATIONS):
    LOCATION = random.choice(['tokyo','wakkanai','minamidaito'])
    YEAR = random.choice(np.arange(2005,2015))
    capm = CAPM(LOCATION,YEAR,shuffle=True, trainmode=True) #instantiate the CAPM class
    capm.eno = ENO(LOCATION,YEAR, shuffle=True, day_balance=True) #instantiate the environment inside the CAPM class
    capm.HMAX = capm.eno.SMAX #maximum power output of solar cell is set in CAPM object using the value in ENO object
#     clear_output()
    print('Iteration {}:  {}, {} '.format(iteration, LOCATION.upper(), YEAR))

    s, r, day_end, year_end = capm.reset()
    record = np.empty(4) #record for battery, henergy, reward and action
    transition_rec = np.zeros((capm.eno.TIME_STEPS, N_STATES * 2 + 2)) #record all the transition in one day

    while True:
        a = dqn.choose_action(s)

        # present state = [batt, enp, henergy]
        record = np.vstack((record, [s[0],s[2],r, a])) # record battery, henergy, reward and action for troubleshooting
                                                       # However, we are interested only in the reward

        # take action
        s_, r, day_end, year_end = capm.step(a)

        temp_transitions = np.hstack((s, [a, r], s_))
        transition_rec[capm.eno.hr-1,:] = temp_transitions

        if (day_end):
            transition_rec[:,5] = r #broadcast reward to all states
            decay_factor = [i for i in (LAMBDA**n for n in reversed(range(0, capm.eno.TIME_STEPS)))]
            transition_rec[:,5] = transition_rec[:,5] * decay_factor #decay reward proportionately
            dqn.store_day_transition(transition_rec)

        if dqn.memory_counter > MEMORY_CAPACITY:
            dqn.learn()

        if (year_end):
    #             print("End of Year")
            break

        # transition to new state
        s = s_

    record = np.delete(record, 0, 0) #remove the first row which is garbage
    reward_rec = record[:,2] #extract reward information from the record array
    reward_rec = reward_rec[reward_rec != 0] #remove all zero rewards in the middle of the days
    print("Average Reward \t\t= {:8.3f}".format(np.mean(reward_rec)))

    # Check if reward beats the High Score and possible save it    
    if (iteration > 19): #save the best models only after 20 iterations
        print("Best Score \t = {:8.3f} @ Iteration No. {}".format(best_avg_reward, best_iteration))
        if(best_avg_reward < np.mean(reward_rec)):
            best_iteration = iteration
            best_avg_reward = np.mean(reward_rec)
            print("Saving Model")
            torch.save(dqn.eval_net.state_dict(), BFILENAME)
    else:
        print("\r")
    # Log the average reward in avg_reward_rec
    avg_reward_rec = np.append(avg_reward_rec, np.mean(reward_rec))

    # End of training
# Save the last model
torch.save(dqn.eval_net.state_dict(), TFILENAME) 

# Plot the average reward log
plt.plot(avg_reward_rec,'b')
plt.ylim([-3,1])
# Out:
# TRAINING IN PROGRESS
#
# Iteration 0:  TOKYO, 2008
# Average Reward 		=   -0.375
#
# Iteration 1:  TOKYO, 2006
# Average Reward 		=   -0.596
#
# Iteration 2:  TOKYO, 2012
# Average Reward 		=   -0.703
#
# Iteration 3:  WAKKANAI, 2014
# Average Reward 		=   -0.373
#
# Iteration 4:  WAKKANAI, 2012
# Average Reward 		=   -0.366
#
# Iteration 5:  WAKKANAI, 2005
# Average Reward 		=   -0.667
#
# Iteration 6:  MINAMIDAITO, 2011
# Average Reward 		=   -0.693
#
# Iteration 7:  MINAMIDAITO, 2008
# Average Reward 		=   -0.776
#
# Iteration 8:  TOKYO, 2008
# Average Reward 		=   -0.443
#
# Iteration 9:  MINAMIDAITO, 2014
# Average Reward 		=   -0.407
#
# Iteration 10:  MINAMIDAITO, 2009
# Average Reward 		=   -0.109
#
# Iteration 11:  WAKKANAI, 2009
# Average Reward 		=   -0.743
#
# Iteration 12:  MINAMIDAITO, 2007
# Average Reward 		=   -0.788
#
# Iteration 13:  WAKKANAI, 2014
# Average Reward 		=   -1.060
#
# Iteration 14:  MINAMIDAITO, 2010
# Average Reward 		=   -0.739
#
# Iteration 15:  TOKYO, 2009
# Average Reward 		=   -0.708
#
# Iteration 16:  MINAMIDAITO, 2006
# Average Reward 		=   -0.751
#
# Iteration 17:  TOKYO, 2011
# Average Reward 		=   -0.712
#
# Iteration 18:  MINAMIDAITO, 2014
# Average Reward 		=   -0.868
#
# Iteration 19:  MINAMIDAITO, 2013
# Average Reward 		=   -0.883
#
# Iteration 20:  MINAMIDAITO, 2011
# Average Reward 		=   -0.779
# Best Score 	 = -1000.000 @ Iteration No. -1
# Saving Model
# Iteration 21:  WAKKANAI, 2008
# Average Reward 		=   -0.866
# Best Score 	 =   -0.779 @ Iteration No. 20
# Iteration 22:  WAKKANAI, 2008
# Average Reward 		=   -0.811
# Best Score 	 =   -0.779 @ Iteration No. 20
# Iteration 23:  WAKKANAI, 2012
# Average Reward 		=   -0.856
# Best Score 	 =   -0.779 @ Iteration No. 20
# Iteration 24:  WAKKANAI, 2014
# Average Reward 		=   -0.786
# Best Score 	 =   -0.779 @ Iteration No. 20
# Iteration 25:  TOKYO, 2006
# Average Reward 		=   -0.863
# Best Score 	 =   -0.779 @ Iteration No. 20
# Iteration 26:  TOKYO, 2009
# Average Reward 		=   -0.890
# Best Score 	 =   -0.779 @ Iteration No. 20
# Iteration 27:  TOKYO, 2005
# Average Reward 		=   -0.676
# Best Score 	 =   -0.779 @ Iteration No. 20
# Saving Model
# Iteration 28:  WAKKANAI, 2011
# Average Reward 		=   -0.816
# Best Score 	 =   -0.676 @ Iteration No. 27
# Iteration 29:  MINAMIDAITO, 2009
# Average Reward 		=   -0.752
# Best Score 	 =   -0.676 @ Iteration No. 27
# Iteration 30:  WAKKANAI, 2009
# Average Reward 		=   -0.738
# Best Score 	 =   -0.676 @ Iteration No. 27
# Iteration 31:  TOKYO, 2005
# Average Reward 		=   -0.969
# Best Score 	 =   -0.676 @ Iteration No. 27
# Iteration 32:  TOKYO, 2005
# Average Reward 		=   -0.995
# Best Score 	 =   -0.676 @ Iteration No. 27
# Iteration 33:  WAKKANAI, 2006
# Average Reward 		=   -0.761
# Best Score 	 =   -0.676 @ Iteration No. 27
# Iteration 34:  TOKYO, 2005
# Average Reward 		=   -0.734
# Best Score 	 =   -0.676 @ Iteration No. 27
# Iteration 35:  TOKYO, 2013
# Average Reward 		=   -0.858
# Best Score 	 =   -0.676 @ Iteration No. 27
# Iteration 36:  TOKYO, 2014
# Average Reward 		=   -0.611
# Best Score 	 =   -0.676 @ Iteration No. 27
# Saving Model
# Iteration 37:  MINAMIDAITO, 2007
# Average Reward 		=   -0.794
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 38:  TOKYO, 2008
# Average Reward 		=   -0.821
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 39:  MINAMIDAITO, 2007
# Average Reward 		=   -0.911
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 40:  MINAMIDAITO, 2011
# Average Reward 		=   -0.836
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 41:  TOKYO, 2013
# Average Reward 		=   -1.030
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 42:  WAKKANAI, 2011
# Average Reward 		=   -0.801
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 43:  WAKKANAI, 2008
# Average Reward 		=   -0.923
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 44:  WAKKANAI, 2009
# Average Reward 		=   -0.928
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 45:  TOKYO, 2006
# Average Reward 		=   -0.826
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 46:  TOKYO, 2009
# Average Reward 		=   -0.867
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 47:  WAKKANAI, 2013
# Average Reward 		=   -0.778
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 48:  TOKYO, 2014
# Average Reward 		=   -0.831
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 49:  MINAMIDAITO, 2010
# Average Reward 		=   -0.752
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 50:  TOKYO, 2008
# Average Reward 		=   -0.777
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 51:  WAKKANAI, 2014
# Average Reward 		=   -0.848
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 52:  MINAMIDAITO, 2007
# Average Reward 		=   -0.821
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 53:  TOKYO, 2008
# Average Reward 		=   -0.822
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 54:  WAKKANAI, 2010
# Average Reward 		=   -0.790
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 55:  WAKKANAI, 2012
# Average Reward 		=   -1.013
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 56:  MINAMIDAITO, 2005
# Average Reward 		=   -0.911
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 57:  WAKKANAI, 2008
# Average Reward 		=   -0.820
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 58:  WAKKANAI, 2013
# Average Reward 		=   -0.747
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 59:  WAKKANAI, 2008
# Average Reward 		=   -0.662
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 60:  TOKYO, 2009
# Average Reward 		=   -0.804
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 61:  WAKKANAI, 2008
# Average Reward 		=   -0.879
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 62:  TOKYO, 2011
# Average Reward 		=   -0.965
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 63:  TOKYO, 2011
# Average Reward 		=   -0.871
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 64:  MINAMIDAITO, 2009
# Average Reward 		=   -0.855
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 65:  WAKKANAI, 2011
# Average Reward 		=   -0.879
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 66:  MINAMIDAITO, 2005
# Average Reward 		=   -0.906
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 67:  TOKYO, 2008
# Average Reward 		=   -0.759
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 68:  WAKKANAI, 2006
# Average Reward 		=   -0.840
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 69:  MINAMIDAITO, 2010
# Average Reward 		=   -0.741
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 70:  TOKYO, 2011
# Average Reward 		=   -0.878
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 71:  MINAMIDAITO, 2006
# Average Reward 		=   -0.787
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 72:  WAKKANAI, 2010
# Average Reward 		=   -0.876
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 73:  MINAMIDAITO, 2011
# Average Reward 		=   -0.676
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 74:  WAKKANAI, 2009
# Average Reward 		=   -0.797
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 75:  TOKYO, 2013
# Average Reward 		=   -0.864
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 76:  MINAMIDAITO, 2007
# Average Reward 		=   -0.896
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 77:  MINAMIDAITO, 2014
# Average Reward 		=   -0.944
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 78:  WAKKANAI, 2006
# Average Reward 		=   -0.784
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 79:  TOKYO, 2006
# Average Reward 		=   -0.856
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 80:  MINAMIDAITO, 2012
# Average Reward 		=   -0.779
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 81:  WAKKANAI, 2006
# Average Reward 		=   -0.836
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 82:  TOKYO, 2012
# Average Reward 		=   -0.962
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 83:  MINAMIDAITO, 2006
# Average Reward 		=   -0.882
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 84:  MINAMIDAITO, 2008
# Average Reward 		=   -0.824
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 85:  WAKKANAI, 2010
# Average Reward 		=   -0.819
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 86:  MINAMIDAITO, 2007
# Average Reward 		=   -0.797
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 87:  MINAMIDAITO, 2009
# Average Reward 		=   -0.757
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 88:  TOKYO, 2008
# Average Reward 		=   -0.884
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 89:  MINAMIDAITO, 2012
# Average Reward 		=   -0.964
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 90:  WAKKANAI, 2012
# Average Reward 		=   -0.766
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 91:  WAKKANAI, 2013
# Average Reward 		=   -0.695
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 92:  MINAMIDAITO, 2006
# Average Reward 		=   -0.765
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 93:  TOKYO, 2011
# Average Reward 		=   -0.802
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 94:  MINAMIDAITO, 2006
# Average Reward 		=   -0.774
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 95:  MINAMIDAITO, 2010
# Average Reward 		=   -0.868
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 96:  MINAMIDAITO, 2006
# Average Reward 		=   -0.742
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 97:  MINAMIDAITO, 2005
# Average Reward 		=   -1.081
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 98:  MINAMIDAITO, 2014
# Average Reward 		=   -0.890
# Best Score 	 =   -0.611 @ Iteration No. 36
# Iteration 99:  TOKYO, 2012
# Average Reward 		=   -0.724
# Best Score 	 =   -0.611 @ Iteration No. 36
# (-3, 1)

# %%
#BFILENAME -> loads the best model
#TFILENAME -> loads the last model
MODELFILE = BFILENAME
TEST_YEAR = '2018'
dqn = DQN()
for TEST_LOCATION in ['tokyo','wakkanai','minamidaito']:
    test_model(TEST_LOCATION, TEST_YEAR, MODELFILE, dqn)
# Out:
# Year run test (Greedy Policy)
# Model Used:  bestU61BAQP7.pt
# End of Test
# Average Reward for TOKYO,2018 = -2.9890914146787084
# Year run test (Greedy Policy)
# Model Used:  bestU61BAQP7.pt
# End of Test
# Average Reward for WAKKANAI,2018 = -2.9909937470574937
# Year run test (Greedy Policy)
# Model Used:  bestU61BAQP7.pt
# End of Test
# Average Reward for MINAMIDAITO,2018 = -2.9885515728538405

# %%
MODELFILE = TFILENAME
TEST_YEAR = '2018'
dqn = DQN()
for TEST_LOCATION in ['tokyo','wakkanai','minamidaito']:
    test_model(TEST_LOCATION, TEST_YEAR, MODELFILE, dqn)
# Out:
# Year run test (Greedy Policy)
# Model Used:  terminalU61BAQP7.pt
# End of Test
# Average Reward for TOKYO,2018 = -2.9891219420096005
# Year run test (Greedy Policy)
# Model Used:  terminalU61BAQP7.pt
# End of Test
# Average Reward for WAKKANAI,2018 = -2.991014506972753
# Year run test (Greedy Policy)
# Model Used:  terminalU61BAQP7.pt
# End of Test
# Average Reward for MINAMIDAITO,2018 = -2.988597262608434

# %%
# TEST_YEAR = 2018
# for TEST_LOCATION in ['tokyo','wakkanai','minamidaito']:
#     test_model(TEST_LOCATION, TEST_YEAR)

# %%
# dqn = DQN()
# capm = CAPM(TEST_LOCATION,TEST_YEAR, shuffle=False, trainmode=False) #if reset is True
# capm.eno = ENO(TEST_LOCATION,TEST_YEAR, shuffle=False, day_balance=False) #instantiate the environment inside the CAPM class
# capm.HMAX = capm.eno.SMAX #maximum power output of solar cell is set in CAPM object using the value in ENO object


# # load the required model
# dqn.eval_net.load_state_dict(torch.load(MODELFILE))
# dqn.eval_net.eval()
# print('Model Used: ',MODELFILE)

# s, r, day_end, year_end = capm.reset()
# yr_test_record = np.empty(4)

# while True:
#     a = dqn.choose_greedy_action(s)

#     #state = [batt, enp, henergy, fcast]
#     yr_test_record = np.vstack((yr_test_record, [s[0],s[2],r, a])) #record battery, henergy, reward and action

#     # take action
#     s_, r, day_end, year_end = capm.step(a)
    
# #     if day_end:
# #         if (capm.BMIN ==capm.batt or capm.batt == capm.BMAX):
# #             capm.batt = capm.BOPT
        

#     if year_end:
#         print("End of Test")
#         break

#     s = s_

# yr_test_record = np.delete(yr_test_record, 0, 0) #remove the first row which is garbage

# #Plot the reward and battery for the entire year run
# title = TEST_LOCATION.upper() + ',' + str(TEST_YEAR)

# NO_OF_DAYS = capm.eno.NO_OF_DAYS
# yr_test_reward_rec = yr_test_record[:,2]
# yr_test_reward_rec = yr_test_reward_rec[yr_test_reward_rec != 0]
# print('Average Reward for',title, '=', np.mean(yr_test_reward_rec))


# fig = plt.figure(figsize=(24,10))
# fig.suptitle(title, fontsize=15)

# #     ax1 = fig.add_subplot(211)
# #     ax1.plot(yr_test_reward_rec)
# #     ax1.set_title("\n\nYear Run Reward")
# #     ax1.set_ylim([-3,1])

# ax2 = fig.add_subplot(111)
# ax2.plot(yr_test_record[:,0],'r')
# ax2.set_title("\n\nYear Run Battery")
# ax2.set_ylim([0,1])
# plt.sca(ax2)
# plt.xticks(np.arange(0, NO_OF_DAYS*24, 50*24),np.arange(0,NO_OF_DAYS,50))

# fig.tight_layout()
# plt.show()

# %%
# #Plot the reward and battery for the entire year run on a day by day basis
# title = TEST_LOCATION.upper() + ',' + str(TEST_YEAR)
# TIME_AXIS = np.arange(0,capm.eno.TIME_STEPS)
# for DAY in range(150,170):#capm.eno.NO_OF_DAYS):
#     START = DAY*24
#     END = START+24

#     daytitle = title + ' - DAY ' + str(DAY)
#     fig = plt.figure(figsize=(16,4))
#     st = fig.suptitle(daytitle)

#     ax2 = fig.add_subplot(121)
#     ax2.plot(yr_test_record[START:END,1],'g')
#     ax2.set_title("HARVESTED ENERGY")
#     plt.xlabel("Hour")
#     ax2.set_ylim([0,1])

#     #plot battery for year run
#     ax1 = fig.add_subplot(122)
#     ax1.plot(TIME_AXIS,yr_test_record[START:END,0],'r') 
# #     ax1.plot(TIME_AXIS, np.ones(capm.eno.TIME_STEPS)*capm.BOPT/capm.BMAX,'r--')
#     ax1.plot(TIME_AXIS, np.ones(capm.eno.TIME_STEPS)*yr_test_record[START,0],'r--')
#     ax1.text(0.1, 0.2, "BINIT = %.2f\n" %(yr_test_record[START,0]),fontsize=11, ha='left')
#     ax1.text(0.1, 0.4, "TENP = %.2f\n" %(capm.BOPT/capm.BMAX-yr_test_record[END,0]),fontsize=11, ha='left')
#     ax1.text(0.1, 0.3, "BMEAN = %.2f\n" %(np.mean(yr_test_record[START:END,0])),fontsize=11, ha='left')



#     ax1.set_title("YEAR RUN TEST")
#     if END < (capm.eno.NO_OF_DAYS*capm.eno.TIME_STEPS):
#         ax1.text(0.1, 0, "REWARD = %.2f\n" %(yr_test_record[END,2]),fontsize=13, ha='left')
#     plt.xlabel("Hour")
#     ax1.set_ylabel('Battery', color='r',fontsize=12)
#     ax1.set_ylim([0,1])

#     #plot actions for year run
#     ax1a = ax1.twinx()
#     ax1a.plot(yr_test_record[START:END,3])
#     ax1a.set_ylim([0,N_ACTIONS])
#     ax1a.set_ylabel('Duty Cycle', color='b',fontsize=12)

#     fig.tight_layout()
#     st.set_y(0.95)
#     fig.subplots_adjust(top=0.75)
#     plt.show()
