# %%
# %matplotlib inline

from os.path import dirname, abspath, join
from os import getcwd
import sys

THIS_DIR = getcwd()
CLASS_DIR = abspath(join(THIS_DIR, '../../..', 'dsnclasses'))
sys.path.append(CLASS_DIR)

import random
import string
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from IPython.display import clear_output

from ENOsmall import ENO
from CAPMr3 import CAPM
from NN6a import DQN as DQN
from globalvar import *

# %%
def test_model(TEST_LOCATION, TEST_YEAR, MODELFILE, dqn):

    print('\nYear run test (Greedy Policy)')

#     dqn = DQN()
    capm = CAPM(TEST_LOCATION,TEST_YEAR, shuffle=False, trainmode=False) #if reset is True
    capm.eno = ENO(TEST_LOCATION,TEST_YEAR, shuffle=False, day_balance=False) #instantiate the environment inside the CAPM class
    capm.HMAX = capm.eno.SMAX #maximum power output of solar cell is set in CAPM object using the value in ENO object

    # load the required model
    dqn.eval_net.load_state_dict(torch.load(MODELFILE))
    dqn.eval_net.eval()
    print('Model Used: ',MODELFILE)

    s, r, day_end, year_end = capm.reset()
    yr_test_record = np.empty(4)

    while True:
        a = dqn.choose_greedy_action(s)

        #state = [batt, enp, henergy, fcast]
        yr_test_record = np.vstack((yr_test_record, [s[0],s[2],r, a])) #record battery, henergy, reward and action

        # take action
        s_, r, day_end, year_end = capm.step(a)

        if year_end:
            print("End of Test")
            break

        s = s_

    yr_test_record = np.delete(yr_test_record, 0, 0) #remove the first row which is garbage
    NO_OF_DAYS = capm.eno.NO_OF_DAYS
    yr_test_reward_rec = yr_test_record[:,2]
    yr_test_reward_rec = yr_test_reward_rec[yr_test_reward_rec != 0]
    
    #Plot the reward and battery for the entire year run
    title = TEST_LOCATION.upper() + ',' + str(TEST_YEAR)
    print('Average Reward for',title, '=', np.mean(yr_test_reward_rec))

    fig = plt.figure(figsize=(24,3))
    fig.suptitle(title, fontsize=15)

#     ax1 = fig.add_subplot(211)
#     ax1.plot(yr_test_reward_rec)
#     ax1.set_title("\n\nYear Run Reward")
#     ax1.set_ylim([-3,1])

    ax2 = fig.add_subplot(111)
    ax2.plot(yr_test_record[:,0],'r')
    ax2.set_title("\n\nYear Run Battery")
    ax2.set_ylim([0,1])
    plt.sca(ax2)
    plt.xticks(np.arange(0, NO_OF_DAYS*24, 50*24),np.arange(0,NO_OF_DAYS,50))

    fig.tight_layout()
    plt.show()    
    return 0

# %%
#TRAIN USING data from TOKYO, WAKKANAI and MINAMIDAITO FROM 2005 to 2014
dqn = DQN()

NO_OF_ITERATIONS = 100

best_iteration = -1
best_avg_reward = -1000 #initialize best average reward to very low value
PFILENAME = ''.join(random.choice(string.ascii_uppercase + string.digits) for _ in range(8)) #create random filename
BFILENAME = "best"+PFILENAME + ".pt" #this file stores the best model
TFILENAME = "terminal"+PFILENAME + ".pt" #this file stores the last model

avg_reward_rec = [] #record the yearly average rewards over the entire duration of training
print('\nTRAINING IN PROGRESS\n')

for iteration in range(NO_OF_ITERATIONS):
    LOCATION = random.choice(['tokyo','wakkanai','minamidaito'])
    YEAR = random.choice(np.arange(2005,2015))
    capm = CAPM(LOCATION,YEAR,shuffle=True, trainmode=True) #instantiate the CAPM class
    capm.eno = ENO(LOCATION,YEAR, shuffle=True, day_balance=True) #instantiate the environment inside the CAPM class
    capm.HMAX = capm.eno.SMAX #maximum power output of solar cell is set in CAPM object using the value in ENO object
#     clear_output()
    print('Iteration {}:  {}, {} '.format(iteration, LOCATION.upper(), YEAR))

    s, r, day_end, year_end = capm.reset()
    record = np.empty(4) #record for battery, henergy, reward and action
    transition_rec = np.zeros((capm.eno.TIME_STEPS, N_STATES * 2 + 2)) #record all the transition in one day

    while True:
        a = dqn.choose_action(s)

        # present state = [batt, enp, henergy]
        record = np.vstack((record, [s[0],s[2],r, a])) # record battery, henergy, reward and action for troubleshooting
                                                       # However, we are interested only in the reward

        # take action
        s_, r, day_end, year_end = capm.step(a)

        temp_transitions = np.hstack((s, [a, r], s_))
        transition_rec[capm.eno.hr-1,:] = temp_transitions

        if (day_end):
            transition_rec[:,5] = r #broadcast reward to all states
            decay_factor = [i for i in (LAMBDA**n for n in reversed(range(0, capm.eno.TIME_STEPS)))]
            transition_rec[:,5] = transition_rec[:,5] * decay_factor #decay reward proportionately
            dqn.store_day_transition(transition_rec)

        if dqn.memory_counter > MEMORY_CAPACITY:
            dqn.learn()

        if (year_end):
    #             print("End of Year")
            break

        # transition to new state
        s = s_

    record = np.delete(record, 0, 0) #remove the first row which is garbage
    reward_rec = record[:,2] #extract reward information from the record array
    reward_rec = reward_rec[reward_rec != 0] #remove all zero rewards in the middle of the days
    print("Average Reward \t\t= {:8.3f}".format(np.mean(reward_rec)))

    # Check if reward beats the High Score and possible save it    
    if (iteration > 19): #save the best models only after 20 iterations
        print("Best Score \t = {:8.3f} @ Iteration No. {}".format(best_avg_reward, best_iteration))
        if(best_avg_reward < np.mean(reward_rec)):
            best_iteration = iteration
            best_avg_reward = np.mean(reward_rec)
            print("Saving Model")
            torch.save(dqn.eval_net.state_dict(), BFILENAME)
    else:
        print("\r")
    # Log the average reward in avg_reward_rec
    avg_reward_rec = np.append(avg_reward_rec, np.mean(reward_rec))

    # End of training
# Save the last model
torch.save(dqn.eval_net.state_dict(), TFILENAME) 

# Plot the average reward log
plt.plot(avg_reward_rec,'b')
plt.ylim([-3,1])
# Out:
# TRAINING IN PROGRESS
#
# Iteration 0:  TOKYO, 2008
# Average Reward 		=   -0.743
#
# Iteration 1:  TOKYO, 2007
# Average Reward 		=   -0.386
#
# Iteration 2:  MINAMIDAITO, 2012
# Average Reward 		=   -0.687
#
# Iteration 3:  TOKYO, 2011
# Average Reward 		=   -0.574
#
# Iteration 4:  TOKYO, 2014
# Average Reward 		=   -0.105
#
# Iteration 5:  MINAMIDAITO, 2010
# Average Reward 		=    0.060
#
# Iteration 6:  MINAMIDAITO, 2009
# Average Reward 		=    0.139
#
# Iteration 7:  MINAMIDAITO, 2009
# Average Reward 		=    0.268
#
# Iteration 8:  MINAMIDAITO, 2008
# Average Reward 		=   -0.029
#
# Iteration 9:  WAKKANAI, 2008
# Average Reward 		=    0.173
#
# Iteration 10:  MINAMIDAITO, 2008
# Average Reward 		=   -0.082
#
# Iteration 11:  TOKYO, 2008
# Average Reward 		=   -0.195
#
# Iteration 12:  WAKKANAI, 2007
# Average Reward 		=   -0.135
#
# Iteration 13:  WAKKANAI, 2014
# Average Reward 		=    0.007
#
# Iteration 14:  WAKKANAI, 2007
# Average Reward 		=   -0.195
#
# Iteration 15:  MINAMIDAITO, 2014
# Average Reward 		=   -0.022
#
# Iteration 16:  TOKYO, 2013
# Average Reward 		=    0.018
#
# Iteration 17:  MINAMIDAITO, 2014
# Average Reward 		=   -0.119
#
# Iteration 18:  TOKYO, 2005
# Average Reward 		=    0.094
#
# Iteration 19:  TOKYO, 2013
# Average Reward 		=   -0.254
#
# Iteration 20:  MINAMIDAITO, 2011
# Average Reward 		=   -0.152
# Best Score 	 = -1000.000 @ Iteration No. -1
# Saving Model
# Iteration 21:  TOKYO, 2009
# Average Reward 		=   -0.040
# Best Score 	 =   -0.152 @ Iteration No. 20
# Saving Model
# Iteration 22:  MINAMIDAITO, 2013
# Average Reward 		=   -0.038
# Best Score 	 =   -0.040 @ Iteration No. 21
# Saving Model
# Iteration 23:  TOKYO, 2009
# Average Reward 		=   -0.102
# Best Score 	 =   -0.038 @ Iteration No. 22
# Iteration 24:  WAKKANAI, 2014
# Average Reward 		=    0.056
# Best Score 	 =   -0.038 @ Iteration No. 22
# Saving Model
# Iteration 25:  WAKKANAI, 2012
# Average Reward 		=   -0.160
# Best Score 	 =    0.056 @ Iteration No. 24
# Iteration 26:  MINAMIDAITO, 2009
# Average Reward 		=   -0.140
# Best Score 	 =    0.056 @ Iteration No. 24
# Iteration 27:  TOKYO, 2014
# Average Reward 		=   -0.087
# Best Score 	 =    0.056 @ Iteration No. 24
# Iteration 28:  MINAMIDAITO, 2013
# Average Reward 		=   -0.213
# Best Score 	 =    0.056 @ Iteration No. 24
# Iteration 29:  WAKKANAI, 2013
# Average Reward 		=   -0.103
# Best Score 	 =    0.056 @ Iteration No. 24
# Iteration 30:  MINAMIDAITO, 2008
# Average Reward 		=   -0.179
# Best Score 	 =    0.056 @ Iteration No. 24
# Iteration 31:  MINAMIDAITO, 2006
# Average Reward 		=   -0.092
# Best Score 	 =    0.056 @ Iteration No. 24
# Iteration 32:  TOKYO, 2006
# Average Reward 		=   -0.122
# Best Score 	 =    0.056 @ Iteration No. 24
# Iteration 33:  WAKKANAI, 2010
# Average Reward 		=   -0.062
# Best Score 	 =    0.056 @ Iteration No. 24
# Iteration 34:  TOKYO, 2012
# Average Reward 		=   -0.095
# Best Score 	 =    0.056 @ Iteration No. 24
# Iteration 35:  WAKKANAI, 2014
# Average Reward 		=   -0.056
# Best Score 	 =    0.056 @ Iteration No. 24
# Iteration 36:  WAKKANAI, 2011
# Average Reward 		=    0.198
# Best Score 	 =    0.056 @ Iteration No. 24
# Saving Model
# Iteration 37:  MINAMIDAITO, 2006
# Average Reward 		=    0.138
# Best Score 	 =    0.198 @ Iteration No. 36
# Iteration 38:  MINAMIDAITO, 2009
# Average Reward 		=    0.074
# Best Score 	 =    0.198 @ Iteration No. 36
# Iteration 39:  MINAMIDAITO, 2010
# Average Reward 		=   -0.299
# Best Score 	 =    0.198 @ Iteration No. 36
# Iteration 40:  TOKYO, 2008
# Average Reward 		=   -0.235
# Best Score 	 =    0.198 @ Iteration No. 36
# Iteration 41:  TOKYO, 2012
# Average Reward 		=   -0.200
# Best Score 	 =    0.198 @ Iteration No. 36
# Iteration 42:  WAKKANAI, 2006
# Average Reward 		=   -0.355
# Best Score 	 =    0.198 @ Iteration No. 36
# Iteration 43:  MINAMIDAITO, 2013
# Average Reward 		=   -0.042
# Best Score 	 =    0.198 @ Iteration No. 36
# Iteration 44:  WAKKANAI, 2005
# Average Reward 		=    0.258
# Best Score 	 =    0.198 @ Iteration No. 36
# Saving Model
# Iteration 45:  TOKYO, 2006
# Average Reward 		=   -0.165
# Best Score 	 =    0.258 @ Iteration No. 44
# Iteration 46:  MINAMIDAITO, 2008
# Average Reward 		=   -0.214
# Best Score 	 =    0.258 @ Iteration No. 44
# Iteration 47:  TOKYO, 2005
# Average Reward 		=   -0.236
# Best Score 	 =    0.258 @ Iteration No. 44
# Iteration 48:  MINAMIDAITO, 2013
# Average Reward 		=    0.119
# Best Score 	 =    0.258 @ Iteration No. 44
# Iteration 49:  MINAMIDAITO, 2014
# Average Reward 		=   -0.081
# Best Score 	 =    0.258 @ Iteration No. 44
# Iteration 50:  TOKYO, 2011
# Average Reward 		=    0.018
# Best Score 	 =    0.258 @ Iteration No. 44
# Iteration 51:  MINAMIDAITO, 2012
# Average Reward 		=   -0.150
# Best Score 	 =    0.258 @ Iteration No. 44
# Iteration 52:  MINAMIDAITO, 2006
# Average Reward 		=   -0.245
# Best Score 	 =    0.258 @ Iteration No. 44
# Iteration 53:  WAKKANAI, 2013
# Average Reward 		=   -0.387
# Best Score 	 =    0.258 @ Iteration No. 44
# Iteration 54:  TOKYO, 2006
# Average Reward 		=    0.020
# Best Score 	 =    0.258 @ Iteration No. 44
# Iteration 55:  MINAMIDAITO, 2014
# Average Reward 		=    0.090
# Best Score 	 =    0.258 @ Iteration No. 44
# Iteration 56:  TOKYO, 2013
# Average Reward 		=    0.109
# Best Score 	 =    0.258 @ Iteration No. 44
# Iteration 57:  MINAMIDAITO, 2007
# Average Reward 		=   -0.024
# Best Score 	 =    0.258 @ Iteration No. 44
# Iteration 58:  TOKYO, 2013
# Average Reward 		=    0.083
# Best Score 	 =    0.258 @ Iteration No. 44
# Iteration 59:  MINAMIDAITO, 2011
# Average Reward 		=    0.327
# Best Score 	 =    0.258 @ Iteration No. 44
# Saving Model
# Iteration 60:  WAKKANAI, 2005
# Average Reward 		=    0.059
# Best Score 	 =    0.327 @ Iteration No. 59
# Iteration 61:  TOKYO, 2005
# Average Reward 		=   -0.074
# Best Score 	 =    0.327 @ Iteration No. 59
# Iteration 62:  MINAMIDAITO, 2011
# Average Reward 		=   -0.084
# Best Score 	 =    0.327 @ Iteration No. 59
# Iteration 63:  WAKKANAI, 2013
# Average Reward 		=   -0.042
# Best Score 	 =    0.327 @ Iteration No. 59
# Iteration 64:  TOKYO, 2007
# Average Reward 		=    0.239
# Best Score 	 =    0.327 @ Iteration No. 59
# Iteration 65:  MINAMIDAITO, 2005
# Average Reward 		=   -0.044
# Best Score 	 =    0.327 @ Iteration No. 59
# Iteration 66:  MINAMIDAITO, 2012
# Average Reward 		=   -0.297
# Best Score 	 =    0.327 @ Iteration No. 59
# Iteration 67:  WAKKANAI, 2012
# Average Reward 		=   -0.095
# Best Score 	 =    0.327 @ Iteration No. 59
# Iteration 68:  MINAMIDAITO, 2014
# Average Reward 		=   -0.380
# Best Score 	 =    0.327 @ Iteration No. 59
# Iteration 69:  WAKKANAI, 2013
# Average Reward 		=   -0.007
# Best Score 	 =    0.327 @ Iteration No. 59
# Iteration 70:  MINAMIDAITO, 2006
# Average Reward 		=   -0.239
# Best Score 	 =    0.327 @ Iteration No. 59
# Iteration 71:  TOKYO, 2007
# Average Reward 		=   -0.053
# Best Score 	 =    0.327 @ Iteration No. 59
# Iteration 72:  MINAMIDAITO, 2013
# Average Reward 		=   -0.116
# Best Score 	 =    0.327 @ Iteration No. 59
# Iteration 73:  MINAMIDAITO, 2012
# Average Reward 		=   -0.080
# Best Score 	 =    0.327 @ Iteration No. 59
# Iteration 74:  TOKYO, 2008
# Average Reward 		=   -0.410
# Best Score 	 =    0.327 @ Iteration No. 59
# Iteration 75:  TOKYO, 2005
# Average Reward 		=   -0.123
# Best Score 	 =    0.327 @ Iteration No. 59
# Iteration 76:  TOKYO, 2013
# Average Reward 		=    0.000
# Best Score 	 =    0.327 @ Iteration No. 59
# Iteration 77:  MINAMIDAITO, 2011
# Average Reward 		=   -0.096
# Best Score 	 =    0.327 @ Iteration No. 59
# Iteration 78:  MINAMIDAITO, 2005
# Average Reward 		=   -0.123
# Best Score 	 =    0.327 @ Iteration No. 59
# Iteration 79:  TOKYO, 2013
# Average Reward 		=   -0.027
# Best Score 	 =    0.327 @ Iteration No. 59
# Iteration 80:  TOKYO, 2014
# Average Reward 		=    0.004
# Best Score 	 =    0.327 @ Iteration No. 59
# Iteration 81:  MINAMIDAITO, 2007
# Average Reward 		=   -0.015
# Best Score 	 =    0.327 @ Iteration No. 59
# Iteration 82:  TOKYO, 2008
# Average Reward 		=    0.134
# Best Score 	 =    0.327 @ Iteration No. 59
# Iteration 83:  WAKKANAI, 2007
# Average Reward 		=   -0.259
# Best Score 	 =    0.327 @ Iteration No. 59
# Iteration 84:  WAKKANAI, 2012
# Average Reward 		=   -0.263
# Best Score 	 =    0.327 @ Iteration No. 59
# Iteration 85:  TOKYO, 2007
# Average Reward 		=   -0.146
# Best Score 	 =    0.327 @ Iteration No. 59
# Iteration 86:  WAKKANAI, 2008
# Average Reward 		=   -0.026
# Best Score 	 =    0.327 @ Iteration No. 59
# Iteration 87:  WAKKANAI, 2006
# Average Reward 		=    0.048
# Best Score 	 =    0.327 @ Iteration No. 59
# Iteration 88:  MINAMIDAITO, 2009
# Average Reward 		=   -0.396
# Best Score 	 =    0.327 @ Iteration No. 59
# Iteration 89:  TOKYO, 2013
# Average Reward 		=   -0.257
# Best Score 	 =    0.327 @ Iteration No. 59
# Iteration 90:  WAKKANAI, 2005
# Average Reward 		=    0.222
# Best Score 	 =    0.327 @ Iteration No. 59
# Iteration 91:  WAKKANAI, 2012
# Average Reward 		=   -0.000
# Best Score 	 =    0.327 @ Iteration No. 59
# Iteration 92:  TOKYO, 2009
# Average Reward 		=   -0.411
# Best Score 	 =    0.327 @ Iteration No. 59
# Iteration 93:  WAKKANAI, 2006
# Average Reward 		=   -0.424
# Best Score 	 =    0.327 @ Iteration No. 59
# Iteration 94:  MINAMIDAITO, 2010
# Average Reward 		=   -0.203
# Best Score 	 =    0.327 @ Iteration No. 59
# Iteration 95:  TOKYO, 2007
# Average Reward 		=   -0.212
# Best Score 	 =    0.327 @ Iteration No. 59
# Iteration 96:  TOKYO, 2012
# Average Reward 		=   -0.172
# Best Score 	 =    0.327 @ Iteration No. 59
# Iteration 97:  WAKKANAI, 2006
# Average Reward 		=   -0.015
# Best Score 	 =    0.327 @ Iteration No. 59
# Iteration 98:  WAKKANAI, 2014
# Average Reward 		=    0.269
# Best Score 	 =    0.327 @ Iteration No. 59
# Iteration 99:  TOKYO, 2013
# Average Reward 		=   -0.245
# Best Score 	 =    0.327 @ Iteration No. 59
# (-3, 1)

# %%
#BFILENAME -> loads the best model
#TFILENAME -> loads the last model
MODELFILE = BFILENAME
TEST_YEAR = '2018'
dqn = DQN()
for TEST_LOCATION in ['tokyo','wakkanai','minamidaito']:
    test_model(TEST_LOCATION, TEST_YEAR, MODELFILE, dqn)
# Out:
# Year run test (Greedy Policy)
# Model Used:  bestLFQHKG6N.pt
# End of Test
# Average Reward for TOKYO,2018 = -2.7656584791413117
# Year run test (Greedy Policy)
# Model Used:  bestLFQHKG6N.pt
# End of Test
# Average Reward for WAKKANAI,2018 = -2.8729344071158645
# Year run test (Greedy Policy)
# Model Used:  bestLFQHKG6N.pt
# End of Test
# Average Reward for MINAMIDAITO,2018 = -1.5580574173814064

# %%
MODELFILE = TFILENAME
TEST_YEAR = '2018'
dqn = DQN()
for TEST_LOCATION in ['tokyo','wakkanai','minamidaito']:
    test_model(TEST_LOCATION, TEST_YEAR, MODELFILE, dqn)
# Out:
# Year run test (Greedy Policy)
# Model Used:  terminalLFQHKG6N.pt
# End of Test
# Average Reward for TOKYO,2018 = -2.989994603132789
# Year run test (Greedy Policy)
# Model Used:  terminalLFQHKG6N.pt
# End of Test
# Average Reward for WAKKANAI,2018 = -2.9907266007605964
# Year run test (Greedy Policy)
# Model Used:  terminalLFQHKG6N.pt
# End of Test
# Average Reward for MINAMIDAITO,2018 = -2.9898225458629013

# %%
# TEST_YEAR = 2018
# for TEST_LOCATION in ['tokyo','wakkanai','minamidaito']:
#     test_model(TEST_LOCATION, TEST_YEAR)

# %%
# dqn = DQN()
# capm = CAPM(TEST_LOCATION,TEST_YEAR, shuffle=False, trainmode=False) #if reset is True
# capm.eno = ENO(TEST_LOCATION,TEST_YEAR, shuffle=False, day_balance=False) #instantiate the environment inside the CAPM class
# capm.HMAX = capm.eno.SMAX #maximum power output of solar cell is set in CAPM object using the value in ENO object


# # load the required model
# dqn.eval_net.load_state_dict(torch.load(MODELFILE))
# dqn.eval_net.eval()
# print('Model Used: ',MODELFILE)

# s, r, day_end, year_end = capm.reset()
# yr_test_record = np.empty(4)

# while True:
#     a = dqn.choose_greedy_action(s)

#     #state = [batt, enp, henergy, fcast]
#     yr_test_record = np.vstack((yr_test_record, [s[0],s[2],r, a])) #record battery, henergy, reward and action

#     # take action
#     s_, r, day_end, year_end = capm.step(a)
    
# #     if day_end:
# #         if (capm.BMIN ==capm.batt or capm.batt == capm.BMAX):
# #             capm.batt = capm.BOPT
        

#     if year_end:
#         print("End of Test")
#         break

#     s = s_

# yr_test_record = np.delete(yr_test_record, 0, 0) #remove the first row which is garbage

# #Plot the reward and battery for the entire year run
# title = TEST_LOCATION.upper() + ',' + str(TEST_YEAR)

# NO_OF_DAYS = capm.eno.NO_OF_DAYS
# yr_test_reward_rec = yr_test_record[:,2]
# yr_test_reward_rec = yr_test_reward_rec[yr_test_reward_rec != 0]
# print('Average Reward for',title, '=', np.mean(yr_test_reward_rec))


# fig = plt.figure(figsize=(24,10))
# fig.suptitle(title, fontsize=15)

# #     ax1 = fig.add_subplot(211)
# #     ax1.plot(yr_test_reward_rec)
# #     ax1.set_title("\n\nYear Run Reward")
# #     ax1.set_ylim([-3,1])

# ax2 = fig.add_subplot(111)
# ax2.plot(yr_test_record[:,0],'r')
# ax2.set_title("\n\nYear Run Battery")
# ax2.set_ylim([0,1])
# plt.sca(ax2)
# plt.xticks(np.arange(0, NO_OF_DAYS*24, 50*24),np.arange(0,NO_OF_DAYS,50))

# fig.tight_layout()
# plt.show()

# %%
# #Plot the reward and battery for the entire year run on a day by day basis
# title = TEST_LOCATION.upper() + ',' + str(TEST_YEAR)
# TIME_AXIS = np.arange(0,capm.eno.TIME_STEPS)
# for DAY in range(150,170):#capm.eno.NO_OF_DAYS):
#     START = DAY*24
#     END = START+24

#     daytitle = title + ' - DAY ' + str(DAY)
#     fig = plt.figure(figsize=(16,4))
#     st = fig.suptitle(daytitle)

#     ax2 = fig.add_subplot(121)
#     ax2.plot(yr_test_record[START:END,1],'g')
#     ax2.set_title("HARVESTED ENERGY")
#     plt.xlabel("Hour")
#     ax2.set_ylim([0,1])

#     #plot battery for year run
#     ax1 = fig.add_subplot(122)
#     ax1.plot(TIME_AXIS,yr_test_record[START:END,0],'r') 
# #     ax1.plot(TIME_AXIS, np.ones(capm.eno.TIME_STEPS)*capm.BOPT/capm.BMAX,'r--')
#     ax1.plot(TIME_AXIS, np.ones(capm.eno.TIME_STEPS)*yr_test_record[START,0],'r--')
#     ax1.text(0.1, 0.2, "BINIT = %.2f\n" %(yr_test_record[START,0]),fontsize=11, ha='left')
#     ax1.text(0.1, 0.4, "TENP = %.2f\n" %(capm.BOPT/capm.BMAX-yr_test_record[END,0]),fontsize=11, ha='left')
#     ax1.text(0.1, 0.3, "BMEAN = %.2f\n" %(np.mean(yr_test_record[START:END,0])),fontsize=11, ha='left')



#     ax1.set_title("YEAR RUN TEST")
#     if END < (capm.eno.NO_OF_DAYS*capm.eno.TIME_STEPS):
#         ax1.text(0.1, 0, "REWARD = %.2f\n" %(yr_test_record[END,2]),fontsize=13, ha='left')
#     plt.xlabel("Hour")
#     ax1.set_ylabel('Battery', color='r',fontsize=12)
#     ax1.set_ylim([0,1])

#     #plot actions for year run
#     ax1a = ax1.twinx()
#     ax1a.plot(yr_test_record[START:END,3])
#     ax1a.set_ylim([0,N_ACTIONS])
#     ax1a.set_ylabel('Duty Cycle', color='b',fontsize=12)

#     fig.tight_layout()
#     st.set_y(0.95)
#     fig.subplots_adjust(top=0.75)
#     plt.show()
